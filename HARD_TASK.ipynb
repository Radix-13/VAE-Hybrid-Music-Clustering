# %%
# ========================================
# CELL 1: Setup and Installation
# ========================================
# !pip install umap-learn -q

from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import (
silhouette_score, calinski_harabasz_score,
davies_bouldin_score, adjusted_rand_score,
normalized_mutual_info_score)
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model
import umap
from sklearn.manifold import TSNE
import warnings
warnings.filterwarnings('ignore')
import os # Import os module for path operations

print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))
# Out:
# Mounted at /content/drive
# TensorFlow version: 2.19.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Define base_path early for consistent file saving
base_path = '/content/drive/MyDrive/VAE for Hybrid Language Music Clustering'

# Ensure the base results directory exists
os.makedirs(base_path, exist_ok=True)

# %%
print("="*60)
print("LOADING DATA FOR HARD TASK")
print("="*60)

# Load all files
dataset = pd.read_csv('/content/drive/MyDrive/VAE for Hybrid Language Music Clustering/Dataset/dataset.csv')
processed_ids = np.load('/content/drive/MyDrive/VAE for Hybrid Language Music Clustering/Dataset/processed_ids.npy')
lyrics_embeddings = np.load('/content/drive/MyDrive/VAE for Hybrid Language Music Clustering/Dataset/Copy of lyrics_embeddings.npy')
spectrograms = np.load('/content/drive/MyDrive/VAE for Hybrid Language Music Clustering/Dataset/processed_spectrograms.npy')

print(f"\n✓ Dataset shape: {dataset.shape}")
print(f"✓ Processed IDs shape: {processed_ids.shape}")
print(f"✓ Lyrics embeddings shape: {lyrics_embeddings.shape}")
print(f"✓ Spectrograms shape: {spectrograms.shape}")

print(f"\nDataset columns: {dataset.columns.tolist()}")
print(f"\nFirst few rows:")
print(dataset.head())


label_columns = []
for col in ['genre', 'label', 'language', 'category']:
    if col in dataset.columns:
        label_columns.append(col)
        print(f"\n✓ Found label column: {col}")
        print(f"  Unique values: {dataset[col].nunique()}")
        print(f"  Distribution:\n{dataset[col].value_counts()}")

has_labels = len(label_columns) > 0
# Out:
# ============================================================
# LOADING DATA FOR HARD TASK
# ============================================================
#
# ✓ Dataset shape: (796, 5)
# ✓ Processed IDs shape: (683,)
# ✓ Lyrics embeddings shape: (683, 384)
# ✓ Spectrograms shape: (683, 128, 256)
#
# Dataset columns: ['id', 'title', 'audio_path', 'genre', 'lyrics']
#
# First few rows:
#        id                    title  \
# 0  711734    Yall Come Back Saloon
# 1   82203                Beers Ago
# 2  445332               Have Mercy
# 3  541844  Memphis in the Meantime
# 4  228626       Good Hearted Woman
#
#                                           audio_path    genre  \
# 0  data/audio/Y'all Come Back Saloon [Hmae3bOX_X0...  country
# 1             data/audio/Beers Ago [Hosifr6ycwU].wav  country
# 2  data/audio/What a Friend We Have in Jesus [ttN...  country
# 3  data/audio/Memphis In The Meantime [KxhE-2apva...  country
# 4  data/audio/A Good Hearted Woman (Live at Weste...  country
#
#                                               lyrics
# 0  She played tambourine with a silver jingle\nAn...
# 1  [Verse 1]\nI had a hand-me-down ride painted r...
# 2  Have mercy on me, baby\nI'm down upon my knees...
# 3  I got something to say little girl\nYou might ...
# 4  [Verse 1]\nA long time forgotten\nOur dreams h...
#
# ✓ Found label column: genre
#   Unique values: 5
#   Distribution:
# genre
# rock       199
# rap        197
# pop        176
# country    143
# rb          81
# Name: count, dtype: int64

# %%
# ========================================
# CELL 3: Prepare Multi-Modal Data
# ========================================
print("\n" + "="*60)
print("PREPARING MULTI-MODAL DATA")
print("="*60)

print("\n1. Processing Spectrograms...")
if len(spectrograms.shape) == 3:

    n_samples = spectrograms.shape[0]
    time_steps = spectrograms.shape[1]
    freq_bins = spectrograms.shape[2]


    spec_cnn = spectrograms.reshape(n_samples, time_steps, freq_bins, 1)

    spec_flat = spectrograms.reshape(n_samples, -1)

    print(f"   CNN format: {spec_cnn.shape}")
    print(f"   Flat format: {spec_flat.shape}")
else:
    raise ValueError(f"Unexpected spectrogram shape: {spectrograms.shape}")

# Normalize spectrograms
spec_cnn_normalized = (spec_cnn - np.mean(spec_cnn)) / (np.std(spec_cnn) + 1e-8)
spec_flat_normalized = StandardScaler().fit_transform(spec_flat)

# 2. Prepare Lyrics Embeddings
print("\n2. Processing Lyrics Embeddings...")
lyrics_normalized = StandardScaler().fit_transform(lyrics_embeddings)
print(f"   Lyrics shape: {lyrics_normalized.shape}")

# 3. Extract Genre Information (if available)
print("\n3. Processing Genre/Label Information...")
if has_labels:
    # Use first available label column
    label_col = label_columns[0]


    filtered_dataset = dataset[dataset['id'].isin(processed_ids)]

    labels_raw = filtered_dataset[label_col].values


    le = LabelEncoder()
    labels_encoded = le.fit_transform(labels_raw)
    n_classes = len(le.classes_)

    # One-hot encode for CVAE
    labels_onehot = tf.keras.utils.to_categorical(labels_encoded, n_classes)

    print(f"   Using column: {label_col}")
    print(f"   Number of classes: {n_classes}")
    print(f"   Classes: {le.classes_}")
    print(f"   One-hot shape: {labels_onehot.shape}")
else:
    labels_encoded = None
    labels_onehot = None
    n_classes = 5  # Default
    print("   No labels found - using default settings")

print("\n✓ All data prepared successfully!")
# Out:
# ============================================================
# PREPARING MULTI-MODAL DATA
# ============================================================
#
# 1. Processing Spectrograms...
#    CNN format: (683, 128, 256, 1)
#    Flat format: (683, 32768)
#
# 2. Processing Lyrics Embeddings...
#    Lyrics shape: (683, 384)
#
# 3. Processing Genre/Label Information...
#    Using column: genre
#    Number of classes: 5
#    Classes: ['country' 'pop' 'rap' 'rb' 'rock']
#    One-hot shape: (683, 5)
#
# ✓ All data prepared successfully!

# %%
# ========================================
# CELL 4: Build Beta-VAE
# ========================================
print("\n" + "="*60)
print("BUILDING BETA-VAE")
print("="*60)

latent_dim = 128
beta = 4.0  # Higher beta encourages disentanglement

# Encoder for flattened spectrograms
spec_input = keras.Input(shape=(spec_flat_normalized.shape[1],), name='spec_input')
x = layers.Dense(2048, activation='relu')(spec_input)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(1024, activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.BatchNormalization()(x)

z_mean_beta = layers.Dense(latent_dim, name='z_mean_beta')(x)
z_log_var_beta = layers.Dense(latent_dim, name='z_log_var_beta')(x)

class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

z_beta = Sampling()([z_mean_beta, z_log_var_beta])
beta_encoder = Model(spec_input, [z_mean_beta, z_log_var_beta, z_beta], name='beta_encoder')

# Decoder
latent_input_beta = keras.Input(shape=(latent_dim,))
x = layers.Dense(512, activation='relu')(latent_input_beta)
x = layers.BatchNormalization()(x)
x = layers.Dense(1024, activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Dense(2048, activation='relu')(x)
x = layers.BatchNormalization()(x)
decoder_output_beta = layers.Dense(spec_flat_normalized.shape[1], activation='sigmoid')(x)

beta_decoder = Model(latent_input_beta, decoder_output_beta, name='beta_decoder')

# Beta-VAE Model
class BetaVAE(keras.Model):
    def __init__(self, encoder, decoder, beta=4.0, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.beta = beta
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.recon_loss_tracker = keras.metrics.Mean(name="recon_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [self.total_loss_tracker, self.recon_loss_tracker, self.kl_loss_tracker]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)

            recon_loss = tf.reduce_mean(tf.square(data - reconstruction))
            kl_loss = -0.5 * tf.reduce_mean(
                1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
            )

            total_loss = recon_loss + self.beta * kl_loss

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        self.total_loss_tracker.update_state(total_loss)
        self.recon_loss_tracker.update_state(recon_loss)
        self.kl_loss_tracker.update_state(kl_loss)

        return {
            "loss": self.total_loss_tracker.result(),
            "recon_loss": self.recon_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data):
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)

        recon_loss = tf.reduce_mean(tf.square(data - reconstruction))
        kl_loss = -0.5 * tf.reduce_mean(
            1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
        )
        total_loss = recon_loss + self.beta * kl_loss

        return {"loss": total_loss, "recon_loss": recon_loss, "kl_loss": kl_loss}

beta_vae = BetaVAE(beta_encoder, beta_decoder, beta=beta)
beta_vae.compile(optimizer=keras.optimizers.Adam(1e-4))

print(f"\n✓ Beta-VAE built with beta={beta}, latent_dim={latent_dim}")
# Out:
# ============================================================
# BUILDING BETA-VAE
# ============================================================
#
# ✓ Beta-VAE built with beta=4.0, latent_dim=128

# %%
# ========================================
# CELL 5: Build Conditional VAE (CVAE)
# ========================================
print("\n" + "="*60)
print("BUILDING CONDITIONAL VAE (CVAE)")
print("="*60)

if has_labels:
    latent_dim_cvae = 128

    # Encoder with condition
    spec_input_cvae = keras.Input(shape=(spec_flat_normalized.shape[1],), name='spec_input_cvae')
    condition_input = keras.Input(shape=(n_classes,), name='condition_input')

    # Concatenate input with condition
    combined = layers.Concatenate()([spec_input_cvae, condition_input])

    x = layers.Dense(2048, activation='relu')(combined)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(1024, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.BatchNormalization()(x)

    z_mean_cvae = layers.Dense(latent_dim_cvae, name='z_mean_cvae')(x)
    z_log_var_cvae = layers.Dense(latent_dim_cvae, name='z_log_var_cvae')(x)
    z_cvae = Sampling()([z_mean_cvae, z_log_var_cvae])

    cvae_encoder = Model([spec_input_cvae, condition_input],
                         [z_mean_cvae, z_log_var_cvae, z_cvae],
                         name='cvae_encoder')

    # Decoder with condition
    latent_input_cvae = keras.Input(shape=(latent_dim_cvae,))
    condition_input_dec = keras.Input(shape=(n_classes,))

    combined_dec = layers.Concatenate()([latent_input_cvae, condition_input_dec])

    x = layers.Dense(512, activation='relu')(combined_dec)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(1024, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(2048, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    decoder_output_cvae = layers.Dense(spec_flat_normalized.shape[1], activation='sigmoid')(x)

    cvae_decoder = Model([latent_input_cvae, condition_input_dec],
                         decoder_output_cvae,
                         name='cvae_decoder')

    # CVAE Model
    class CVAE(keras.Model):
        def __init__(self, encoder, decoder, **kwargs):
            super().__init__(**kwargs)
            self.encoder = encoder
            self.decoder = decoder
            self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
            self.recon_loss_tracker = keras.metrics.Mean(name="recon_loss")
            self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

        @property
        def metrics(self):
            return [self.total_loss_tracker, self.recon_loss_tracker, self.kl_loss_tracker]

        def train_step(self, data):
            spec_data, condition_data = data

            with tf.GradientTape() as tape:
                z_mean, z_log_var, z = self.encoder([spec_data, condition_data])
                reconstruction = self.decoder([z, condition_data])

                recon_loss = tf.reduce_mean(tf.square(spec_data - reconstruction))
                kl_loss = -0.5 * tf.reduce_mean(
                    1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
                )

                total_loss = recon_loss + kl_loss

            grads = tape.gradient(total_loss, self.trainable_weights)
            self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

            self.total_loss_tracker.update_state(total_loss)
            self.recon_loss_tracker.update_state(recon_loss)
            self.kl_loss_tracker.update_state(kl_loss)

            return {
                "loss": self.total_loss_tracker.result(),
                "recon_loss": self.recon_loss_tracker.result(),
                "kl_loss": self.kl_loss_tracker.result(),
            }

        def test_step(self, data):
            spec_data, condition_data = data
            z_mean, z_log_var, z = self.encoder([spec_data, condition_data])
            reconstruction = self.decoder([z, condition_data])

            recon_loss = tf.reduce_mean(tf.square(spec_data - reconstruction))
            kl_loss = -0.5 * tf.reduce_mean(
                1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
            )
            total_loss = recon_loss + kl_loss

            return {
                "loss": total_loss,
                "recon_loss": recon_loss,
                "kl_loss": kl_loss
            }

    cvae = CVAE(cvae_encoder, cvae_decoder)
    # Set run_eagerly=True before compiling the model
    cvae.run_eagerly = True
    cvae.compile(optimizer=keras.optimizers.Adam(1e-4))

    print(f"✓ CVAE built with latent_dim={latent_dim_cvae}, n_classes={n_classes}")
else:
    cvae = None
    print("⚠️ No labels available - skipping CVAE")
# Out:
# ============================================================
# BUILDING CONDITIONAL VAE (CVAE)
# ============================================================
# ✓ CVAE built with latent_dim=128, n_classes=5

# %%
# ========================================
# CELL 6: Build Multi-Modal VAE (Audio + Lyrics)
# ========================================
print("\n" + "="*60)
print("BUILDING MULTI-MODAL VAE")
print("="*60)

latent_dim_mm = 128

# Audio branch (spectrograms)
audio_input = keras.Input(shape=(spec_flat_normalized.shape[1],), name='audio_input')
x_audio = layers.Dense(1024, activation='relu')(audio_input)
x_audio = layers.BatchNormalization()(x_audio)
x_audio = layers.Dropout(0.3)(x_audio)
x_audio = layers.Dense(512, activation='relu')(x_audio)
x_audio = layers.BatchNormalization()(x_audio)
audio_encoded = layers.Dense(256, activation='relu')(x_audio)

# Lyrics branch
lyrics_input = keras.Input(shape=(lyrics_normalized.shape[1],), name='lyrics_input')
x_lyrics = layers.Dense(512, activation='relu')(lyrics_input)
x_lyrics = layers.BatchNormalization()(x_lyrics)
x_lyrics = layers.Dropout(0.3)(x_lyrics)
x_lyrics = layers.Dense(256, activation='relu')(x_lyrics)
x_lyrics = layers.BatchNormalization()(x_lyrics)
lyrics_encoded = layers.Dense(128, activation='relu')(x_lyrics)

# Fusion
fused = layers.Concatenate()([audio_encoded, lyrics_encoded])
x_fused = layers.Dense(512, activation='relu')(fused)
x_fused = layers.BatchNormalization()(x_fused)
x_fused = layers.Dropout(0.3)(x_fused)

z_mean_mm = layers.Dense(latent_dim_mm, name='z_mean_mm')(x_fused)
z_log_var_mm = layers.Dense(latent_dim_mm, name='z_log_var_mm')(x_fused)
z_mm = Sampling()([z_mean_mm, z_log_var_mm])

mm_encoder = Model([audio_input, lyrics_input],
                   [z_mean_mm, z_log_var_mm, z_mm],
                   name='multimodal_encoder')

# Decoder (reconstruct both modalities)
latent_input_mm = keras.Input(shape=(latent_dim_mm,))

# Audio decoder branch
x_audio_dec = layers.Dense(512, activation='relu')(latent_input_mm)
x_audio_dec = layers.BatchNormalization()(x_audio_dec)
x_audio_dec = layers.Dense(1024, activation='relu')(x_audio_dec)
x_audio_dec = layers.BatchNormalization()(x_audio_dec)
audio_output = layers.Dense(spec_flat_normalized.shape[1], activation='sigmoid', name='audio_output')(x_audio_dec)

# Lyrics decoder branch
x_lyrics_dec = layers.Dense(256, activation='relu')(latent_input_mm)
x_lyrics_dec = layers.BatchNormalization()(x_lyrics_dec)
x_lyrics_dec = layers.Dense(512, activation='relu')(x_lyrics_dec)
x_lyrics_dec = layers.BatchNormalization()(x_lyrics_dec)
lyrics_output = layers.Dense(lyrics_normalized.shape[1], activation='sigmoid', name='lyrics_output')(x_lyrics_dec)

mm_decoder = Model(latent_input_mm, [audio_output, lyrics_output], name='multimodal_decoder')

# Multi-Modal VAE
class MultiModalVAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.audio_recon_loss_tracker = keras.metrics.Mean(name="audio_recon_loss")
        self.lyrics_recon_loss_tracker = keras.metrics.Mean(name="lyrics_recon_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [self.total_loss_tracker, self.audio_recon_loss_tracker,
                self.lyrics_recon_loss_tracker, self.kl_loss_tracker]

    def train_step(self, data):
        # Correctly unpack the data for multi-modal VAE training
        (audio_input, lyrics_input), (audio_target, lyrics_target) = data

        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder([audio_input, lyrics_input])
            audio_recon, lyrics_recon = self.decoder(z)

            audio_recon_loss = tf.reduce_mean(tf.square(audio_target - audio_recon))
            lyrics_recon_loss = tf.reduce_mean(tf.square(lyrics_target - lyrics_recon))

            kl_loss = -0.5 * tf.reduce_mean(
                1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
            )

            total_loss = audio_recon_loss + lyrics_recon_loss + kl_loss

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        self.total_loss_tracker.update_state(total_loss)
        self.audio_recon_loss_tracker.update_state(audio_recon_loss)
        self.lyrics_recon_loss_tracker.update_state(lyrics_recon_loss)
        self.kl_loss_tracker.update_state(kl_loss)

        return {
            "loss": self.total_loss_tracker.result(),
            "audio_recon_loss": self.audio_recon_loss_tracker.result(),
            "lyrics_recon_loss": self.lyrics_recon_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data):
        # Correctly unpack the data for multi-modal VAE testing
        (audio_input, lyrics_input), (audio_target, lyrics_target) = data
        z_mean, z_log_var, z = self.encoder([audio_input, lyrics_input])
        audio_recon, lyrics_recon = self.decoder(z)

        audio_recon_loss = tf.reduce_mean(tf.square(audio_target - audio_recon))
        lyrics_recon_loss = tf.reduce_mean(tf.square(lyrics_target - lyrics_recon))
        kl_loss = -0.5 * tf.reduce_mean(
            1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
        )
        total_loss = audio_recon_loss + lyrics_recon_loss + kl_loss

        return {
            "loss": total_loss,
            "audio_recon_loss": audio_recon_loss,
            "lyrics_recon_loss": lyrics_recon_loss,
            "kl_loss": kl_loss
        }

mm_vae = MultiModalVAE(mm_encoder, mm_decoder)
mm_vae.compile(optimizer=keras.optimizers.Adam(1e-4))

print(f"✓ Multi-Modal VAE built with latent_dim={latent_dim_mm}")

print("\n✓ All models built successfully!")
print(f"  1. Beta-VAE (beta={beta})")
print(f"  2. CVAE (conditional)" if cvae else "  2. CVAE (skipped - no labels)")
print(f"  3. Multi-Modal VAE (audio + lyrics)")
# Out:
# ============================================================
# BUILDING MULTI-MODAL VAE
# ============================================================
# ✓ Multi-Modal VAE built with latent_dim=128
#
# ✓ All models built successfully!
#   1. Beta-VAE (beta=4.0)
#   2. CVAE (conditional)
#   3. Multi-Modal VAE (audio + lyrics)

# %%
# ========================================
# CELL 7: Train Beta-VAE
# ========================================
print("\n" + "="*60)
print("TRAINING BETA-VAE")
print("="*60)

early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True
)

lr_schedule = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=7,
    min_lr=1e-6
)

history_beta = beta_vae.fit(
    spec_flat_normalized,
    epochs=120,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stopping, lr_schedule],
    verbose=1
)

print(f"\n✓ Beta-VAE training complete (epochs: {len(history_beta.history['loss'])})")

# Plot training
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.plot(history_beta.history['loss'], label='Train', linewidth=2)
plt.plot(history_beta.history['val_loss'], label='Val', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Total Loss')
plt.legend()
plt.title('Beta-VAE Total Loss')
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 2)
plt.plot(history_beta.history['recon_loss'], label='Train', linewidth=2)
plt.plot(history_beta.history['val_recon_loss'], label='Val', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Reconstruction Loss')
plt.legend()
plt.title('Beta-VAE Reconstruction')
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 3)
plt.plot(history_beta.history['kl_loss'], label='Train', linewidth=2)
plt.plot(history_beta.history['val_kl_loss'], label='Val', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('KL Loss')
plt.legend()
plt.title('Beta-VAE KL Divergence')
plt.grid(True, alpha=0.3)

plt.tight_layout()

# Ensure the directory exists before saving the plot
output_dir = os.path.join(base_path, 'visualizations')
os.makedirs(output_dir, exist_ok=True)
plt.savefig(os.path.join(output_dir, 'beta_vae_training.png'), dpi=300, bbox_inches='tight')
plt.show()

# Extract latent features
z_mean_beta_features, _, _ = beta_encoder.predict(spec_flat_normalized, verbose=0)
print(f"✓ Beta-VAE latent features: {z_mean_beta_features.shape}")
# Out:
# ============================================================
# TRAINING BETA-VAE
# ============================================================
# Epoch 1/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 22s 445ms/step - kl_loss: 0.3086 - loss: 2.4826 - recon_loss: 1.2481 - val_kl_loss: 0.0342 - val_loss: 1.1746 - val_recon_loss: 1.0377 - learning_rate: 1.0000e-04
# Epoch 2/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - kl_loss: 0.0177 - loss: 1.1594 - recon_loss: 1.0888 - val_kl_loss: 0.0073 - val_loss: 0.9351 - val_recon_loss: 0.9057 - learning_rate: 1.0000e-04
# Epoch 3/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - kl_loss: 0.0014 - loss: 1.0448 - recon_loss: 1.0391 - val_kl_loss: 0.0025 - val_loss: 0.9146 - val_recon_loss: 0.9044 - learning_rate: 1.0000e-04
# Epoch 4/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - kl_loss: 2.4675e-04 - loss: 0.9798 - recon_loss: 0.9788 - val_kl_loss: 0.0014 - val_loss: 0.9121 - val_recon_loss: 0.9064 - learning_rate: 1.0000e-04
# Epoch 5/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - kl_loss: 5.6011e-05 - loss: 1.0115 - recon_loss: 1.0113 - val_kl_loss: 0.0012 - val_loss: 0.9101 - val_recon_loss: 0.9052 - learning_rate: 1.0000e-04
# Epoch 6/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - kl_loss: 1.8966e-05 - loss: 0.9863 - recon_loss: 0.9862 - val_kl_loss: 0.0012 - val_loss: 0.9087 - val_recon_loss: 0.9040 - learning_rate: 1.0000e-04
# Epoch 7/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - kl_loss: 7.1329e-06 - loss: 1.0292 - recon_loss: 1.0292 - val_kl_loss: 0.0012 - val_loss: 0.9130 - val_recon_loss: 0.9084 - learning_rate: 1.0000e-04
# Epoch 8/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - kl_loss: 5.6949e-06 - loss: 1.0246 - recon_loss: 1.0246 - val_kl_loss: 0.0012 - val_loss: 0.9151 - val_recon_loss: 0.9105 - learning_rate: 1.0000e-04
# Epoch 9/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - kl_loss: 5.1399e-06 - loss: 1.0103 - recon_loss: 1.0103 - val_kl_loss: 0.0012 - val_loss: 0.9211 - val_recon_loss: 0.9165 - learning_rate: 1.0000e-04
# Epoch 10/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - kl_loss: 4.5614e-06 - loss: 1.1022 - recon_loss: 1.1022 - val_kl_loss: 0.0011 - val_loss: 0.9159 - val_recon_loss: 0.9113 - learning_rate: 1.0000e-04
# Epoch 11/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - kl_loss: 4.0184e-06 - loss: 1.0085 - recon_loss: 1.0085 - val_kl_loss: 0.0011 - val_loss: 0.9136 - val_recon_loss: 0.9090 - learning_rate: 1.0000e-04
# Epoch 12/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - kl_loss: 3.6175e-06 - loss: 1.0350 - recon_loss: 1.0350 - val_kl_loss: 0.0011 - val_loss: 0.9162 - val_recon_loss: 0.9116 - learning_rate: 1.0000e-04
# Epoch 13/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - kl_loss: 3.2081e-06 - loss: 0.9945 - recon_loss: 0.9945 - val_kl_loss: 0.0011 - val_loss: 0.9196 - val_recon_loss: 0.9150 - learning_rate: 1.0000e-04
# Epoch 14/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - kl_loss: 2.8977e-06 - loss: 1.0539 - recon_loss: 1.0539 - val_kl_loss: 0.0011 - val_loss: 0.9202 - val_recon_loss: 0.9157 - learning_rate: 5.0000e-05
# Epoch 15/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - kl_loss: 2.7453e-06 - loss: 1.0356 - recon_loss: 1.0356 - val_kl_loss: 0.0011 - val_loss: 0.9153 - val_recon_loss: 0.9107 - learning_rate: 5.0000e-05
# Epoch 16/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - kl_loss: 2.5810e-06 - loss: 1.0629 - recon_loss: 1.0629 - val_kl_loss: 0.0011 - val_loss: 0.9141 - val_recon_loss: 0.9095 - learning_rate: 5.0000e-05
# Epoch 17/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - kl_loss: 2.4355e-06 - loss: 1.0355 - recon_loss: 1.0355 - val_kl_loss: 0.0011 - val_loss: 0.9291 - val_recon_loss: 0.9245 - learning_rate: 5.0000e-05
# Epoch 18/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - kl_loss: 2.2816e-06 - loss: 1.0358 - recon_loss: 1.0358 - val_kl_loss: 0.0011 - val_loss: 0.9140 - val_recon_loss: 0.9095 - learning_rate: 5.0000e-05
# Epoch 19/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - kl_loss: 2.1343e-06 - loss: 1.0509 - recon_loss: 1.0508 - val_kl_loss: 0.0011 - val_loss: 0.9089 - val_recon_loss: 0.9043 - learning_rate: 5.0000e-05
# Epoch 20/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - kl_loss: 2.0123e-06 - loss: 1.0073 - recon_loss: 1.0072 - val_kl_loss: 0.0011 - val_loss: 0.9159 - val_recon_loss: 0.9113 - learning_rate: 5.0000e-05
# Epoch 21/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - kl_loss: 1.9015e-06 - loss: 1.0321 - recon_loss: 1.0320 - val_kl_loss: 0.0011 - val_loss: 0.9196 - val_recon_loss: 0.9151 - learning_rate: 2.5000e-05
#
# ✓ Beta-VAE training complete (epochs: 21)
# ✓ Beta-VAE latent features: (683, 128)

# %%
# ========================================
# CELL 8: Train CVAE (if labels available)
# ========================================
if cvae:
    print("\n" + "="*60)
    print("TRAINING CVAE")
    print("="*60)

    early_stopping_cvae = keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True
    )

    lr_schedule_cvae = keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=7,
        min_lr=1e-6
    )

    # Manual split for training and validation since validation_split is not supported for tf.data.Dataset
    from sklearn.model_selection import train_test_split

    # Split data into training and validation sets
    (train_spec, val_spec, train_labels, val_labels) = train_test_split(
        spec_flat_normalized, labels_onehot, test_size=0.2, random_state=42
    )

    # Create tf.data.Dataset for training
    # The dataset should yield (spec_data, condition_data) directly for the custom train_step
    train_dataset = tf.data.Dataset.from_tensor_slices(
        (train_spec, train_labels)
    ).batch(32).prefetch(tf.data.AUTOTUNE)

    # Create tf.data.Dataset for validation
    val_dataset = tf.data.Dataset.from_tensor_slices(
        (val_spec, val_labels)
    ).batch(32).prefetch(tf.data.AUTOTUNE)

    # Set run_eagerly=True to avoid ValueError: Creating variables on a non-first call to a function decorated with tf.function.
    # This allows custom train_step/test_step to operate in eager mode, bypassing tf.function tracing issues.
    cvae.run_eagerly = True

    history_cvae = cvae.fit(
        train_dataset,
        epochs=100,
        validation_data=val_dataset, # Use validation_data for tf.data.Dataset
        callbacks=[early_stopping_cvae, lr_schedule_cvae],
        verbose=1
    )

    print(f"\n✓ CVAE training complete (epochs: {len(history_cvae.history['loss'])})")

    # Plot training
    plt.figure(figsize=(15, 5))
    plt.subplot(1, 3, 1)
    plt.plot(history_cvae.history['loss'], label='Train', linewidth=2)
    plt.plot(history_cvae.history['val_loss'], label='Val', linewidth=2)
    plt.xlabel('Epoch')
    plt.ylabel('Total Loss')
    plt.legend()
    plt.title('CVAE Total Loss')
    plt.grid(True, alpha=0.3)

    plt.subplot(1, 3, 2)
    plt.plot(history_cvae.history['recon_loss'], label='Train', linewidth=2)
    plt.plot(history_cvae.history['val_recon_loss'], label='Val', linewidth=2)
    plt.xlabel('Epoch')
    plt.ylabel('Reconstruction Loss')
    plt.legend()
    plt.title('CVAE Reconstruction')
    plt.grid(True, alpha=0.3)

    plt.subplot(1, 3, 3)
    plt.plot(history_cvae.history['kl_loss'], label='Train', linewidth=2)
    plt.plot(history_cvae.history['val_kl_loss'], label='Val', linewidth=2)
    plt.xlabel('Epoch')
    plt.ylabel('KL Loss')
    plt.legend()
    plt.title('CVAE KL Divergence')
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    output_dir_cvae_vis = os.path.join(base_path, 'visualizations')
    os.makedirs(output_dir_cvae_vis, exist_ok=True)
    plt.savefig(os.path.join(output_dir_cvae_vis, 'cvae_training.png'), dpi=300, bbox_inches='tight')
    plt.show()

    # Extract latent features
    z_mean_cvae_features, _, _ = cvae_encoder.predict([spec_flat_normalized, labels_onehot], verbose=0)
    print(f"✓ CVAE latent features: {z_mean_cvae_features.shape}")
else:
    labels_encoded = None # Ensure labels_encoded is defined as None if no labels.
    z_mean_cvae_features = None
    print("\n Skipping CVAE training (no labels)")
# Out:
# ============================================================
# TRAINING CVAE
# ============================================================
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 13s 537ms/step - kl_loss: 0.3837 - loss: 1.5789 - recon_loss: 1.1952 - val_kl_loss: 0.0456 - val_loss: 0.8513 - val_recon_loss: 0.8057 - learning_rate: 1.0000e-04
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 238ms/step - kl_loss: 0.0523 - loss: 1.0848 - recon_loss: 1.0324 - val_kl_loss: 0.0141 - val_loss: 0.7451 - val_recon_loss: 0.7310 - learning_rate: 1.0000e-04
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 201ms/step - kl_loss: 0.0091 - loss: 0.9804 - recon_loss: 0.9713 - val_kl_loss: 0.0086 - val_loss: 0.7460 - val_recon_loss: 0.7373 - learning_rate: 1.0000e-04
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 265ms/step - kl_loss: 0.0068 - loss: 0.9786 - recon_loss: 0.9718 - val_kl_loss: 0.0064 - val_loss: 0.7443 - val_recon_loss: 0.7380 - learning_rate: 1.0000e-04
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 235ms/step - kl_loss: 0.0087 - loss: 0.9804 - recon_loss: 0.9716 - val_kl_loss: 0.0051 - val_loss: 0.7434 - val_recon_loss: 0.7384 - learning_rate: 1.0000e-04
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - kl_loss: 0.0101 - loss: 0.9820 - recon_loss: 0.9719 - val_kl_loss: 0.0044 - val_loss: 0.7422 - val_recon_loss: 0.7378 - learning_rate: 1.0000e-04
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 242ms/step - kl_loss: 0.0141 - loss: 0.9857 - recon_loss: 0.9716 - val_kl_loss: 0.0045 - val_loss: 0.7429 - val_recon_loss: 0.7384 - learning_rate: 1.0000e-04
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 232ms/step - kl_loss: 0.0138 - loss: 0.9852 - recon_loss: 0.9715 - val_kl_loss: 0.0033 - val_loss: 0.7406 - val_recon_loss: 0.7373 - learning_rate: 1.0000e-04
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - kl_loss: 0.0082 - loss: 0.9801 - recon_loss: 0.9719 - val_kl_loss: 0.0034 - val_loss: 0.7407 - val_recon_loss: 0.7372 - learning_rate: 1.0000e-04
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 274ms/step - kl_loss: 0.0052 - loss: 0.9769 - recon_loss: 0.9717 - val_kl_loss: 0.0031 - val_loss: 0.7401 - val_recon_loss: 0.7370 - learning_rate: 1.0000e-04
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - kl_loss: 0.0019 - loss: 0.9736 - recon_loss: 0.9718 - val_kl_loss: 0.0026 - val_loss: 0.7402 - val_recon_loss: 0.7376 - learning_rate: 1.0000e-04
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 213ms/step - kl_loss: 4.7057e-04 - loss: 0.9722 - recon_loss: 0.9717 - val_kl_loss: 0.0018 - val_loss: 0.7403 - val_recon_loss: 0.7385 - learning_rate: 1.0000e-04
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 254ms/step - kl_loss: 1.4555e-04 - loss: 0.9721 - recon_loss: 0.9720 - val_kl_loss: 0.0015 - val_loss: 0.7368 - val_recon_loss: 0.7353 - learning_rate: 1.0000e-04
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 228ms/step - kl_loss: 1.5796e-04 - loss: 0.9720 - recon_loss: 0.9718 - val_kl_loss: 0.0015 - val_loss: 0.7415 - val_recon_loss: 0.7400 - learning_rate: 1.0000e-04
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - kl_loss: 3.7290e-05 - loss: 0.9722 - recon_loss: 0.9721 - val_kl_loss: 0.0011 - val_loss: 0.7382 - val_recon_loss: 0.7371 - learning_rate: 1.0000e-04
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 199ms/step - kl_loss: 1.9984e-05 - loss: 0.9717 - recon_loss: 0.9717 - val_kl_loss: 0.0011 - val_loss: 0.7390 - val_recon_loss: 0.7380 - learning_rate: 1.0000e-04
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 266ms/step - kl_loss: 1.7108e-05 - loss: 0.9720 - recon_loss: 0.9720 - val_kl_loss: 0.0011 - val_loss: 0.7407 - val_recon_loss: 0.7396 - learning_rate: 1.0000e-04
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 201ms/step - kl_loss: 1.6181e-05 - loss: 0.9714 - recon_loss: 0.9714 - val_kl_loss: 0.0011 - val_loss: 0.7394 - val_recon_loss: 0.7383 - learning_rate: 1.0000e-04
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 201ms/step - kl_loss: 1.5417e-05 - loss: 0.9718 - recon_loss: 0.9718 - val_kl_loss: 0.0011 - val_loss: 0.7395 - val_recon_loss: 0.7384 - learning_rate: 1.0000e-04
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 240ms/step - kl_loss: 1.4936e-05 - loss: 0.9718 - recon_loss: 0.9717 - val_kl_loss: 0.0011 - val_loss: 0.7386 - val_recon_loss: 0.7376 - learning_rate: 1.0000e-04
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 238ms/step - kl_loss: 1.4547e-05 - loss: 0.9722 - recon_loss: 0.9722 - val_kl_loss: 0.0011 - val_loss: 0.7378 - val_recon_loss: 0.7367 - learning_rate: 5.0000e-05
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 209ms/step - kl_loss: 1.4524e-05 - loss: 0.9715 - recon_loss: 0.9715 - val_kl_loss: 0.0011 - val_loss: 0.7377 - val_recon_loss: 0.7366 - learning_rate: 5.0000e-05
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 325ms/step - kl_loss: 1.3977e-05 - loss: 0.9713 - recon_loss: 0.9713 - val_kl_loss: 0.0010 - val_loss: 0.7367 - val_recon_loss: 0.7357 - learning_rate: 5.0000e-05
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - kl_loss: 1.3611e-05 - loss: 0.9711 - recon_loss: 0.9711 - val_kl_loss: 0.0010 - val_loss: 0.7382 - val_recon_loss: 0.7372 - learning_rate: 5.0000e-05
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 222ms/step - kl_loss: 1.3507e-05 - loss: 0.9718 - recon_loss: 0.9717 - val_kl_loss: 0.0011 - val_loss: 0.7392 - val_recon_loss: 0.7381 - learning_rate: 5.0000e-05
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 218ms/step - kl_loss: 1.4639e-05 - loss: 0.9711 - recon_loss: 0.9710 - val_kl_loss: 0.0010 - val_loss: 0.7382 - val_recon_loss: 0.7371 - learning_rate: 5.0000e-05
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 249ms/step - kl_loss: 1.4370e-05 - loss: 0.9712 - recon_loss: 0.9712 - val_kl_loss: 0.0010 - val_loss: 0.7370 - val_recon_loss: 0.7360 - learning_rate: 5.0000e-05
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - kl_loss: 1.3352e-05 - loss: 0.9720 - recon_loss: 0.9720 - val_kl_loss: 0.0010 - val_loss: 0.7389 - val_recon_loss: 0.7378 - learning_rate: 5.0000e-05
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 204ms/step - kl_loss: 1.2980e-05 - loss: 0.9711 - recon_loss: 0.9711 - val_kl_loss: 0.0010 - val_loss: 0.7384 - val_recon_loss: 0.7374 - learning_rate: 5.0000e-05
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 251ms/step - kl_loss: 1.2207e-05 - loss: 0.9717 - recon_loss: 0.9717 - val_kl_loss: 0.0010 - val_loss: 0.7382 - val_recon_loss: 0.7372 - learning_rate: 5.0000e-05
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 234ms/step - kl_loss: 1.2336e-05 - loss: 0.9718 - recon_loss: 0.9718 - val_kl_loss: 0.0010 - val_loss: 0.7360 - val_recon_loss: 0.7350 - learning_rate: 2.5000e-05
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - kl_loss: 1.2107e-05 - loss: 0.9722 - recon_loss: 0.9722 - val_kl_loss: 0.0010 - val_loss: 0.7399 - val_recon_loss: 0.7388 - learning_rate: 2.5000e-05
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 253ms/step - kl_loss: 1.2029e-05 - loss: 0.9717 - recon_loss: 0.9717 - val_kl_loss: 0.0010 - val_loss: 0.7392 - val_recon_loss: 0.7382 - learning_rate: 2.5000e-05
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - kl_loss: 1.1655e-05 - loss: 0.9719 - recon_loss: 0.9719 - val_kl_loss: 0.0010 - val_loss: 0.7366 - val_recon_loss: 0.7356 - learning_rate: 2.5000e-05
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 205ms/step - kl_loss: 1.1642e-05 - loss: 0.9716 - recon_loss: 0.9716 - val_kl_loss: 0.0010 - val_loss: 0.7394 - val_recon_loss: 0.7383 - learning_rate: 2.5000e-05
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 231ms/step - kl_loss: 1.1493e-05 - loss: 0.9717 - recon_loss: 0.9717 - val_kl_loss: 0.0010 - val_loss: 0.7392 - val_recon_loss: 0.7381 - learning_rate: 2.5000e-05
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - kl_loss: 1.1625e-05 - loss: 0.9713 - recon_loss: 0.9713 - val_kl_loss: 0.0010 - val_loss: 0.7384 - val_recon_loss: 0.7374 - learning_rate: 2.5000e-05
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 201ms/step - kl_loss: 1.1466e-05 - loss: 0.9715 - recon_loss: 0.9715 - val_kl_loss: 0.0010 - val_loss: 0.7389 - val_recon_loss: 0.7378 - learning_rate: 2.5000e-05
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 205ms/step - kl_loss: 1.1467e-05 - loss: 0.9713 - recon_loss: 0.9712 - val_kl_loss: 0.0010 - val_loss: 0.7403 - val_recon_loss: 0.7393 - learning_rate: 1.2500e-05
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - kl_loss: 1.1388e-05 - loss: 0.9705 - recon_loss: 0.9704 - val_kl_loss: 0.0010 - val_loss: 0.7357 - val_recon_loss: 0.7347 - learning_rate: 1.2500e-05
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 202ms/step - kl_loss: 1.1315e-05 - loss: 0.9709 - recon_loss: 0.9709 - val_kl_loss: 0.0010 - val_loss: 0.7367 - val_recon_loss: 0.7356 - learning_rate: 1.2500e-05
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 206ms/step - kl_loss: 1.1194e-05 - loss: 0.9714 - recon_loss: 0.9713 - val_kl_loss: 0.0010 - val_loss: 0.7379 - val_recon_loss: 0.7369 - learning_rate: 1.2500e-05
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 252ms/step - kl_loss: 1.1023e-05 - loss: 0.9716 - recon_loss: 0.9716 - val_kl_loss: 0.0010 - val_loss: 0.7359 - val_recon_loss: 0.7348 - learning_rate: 1.2500e-05
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 210ms/step - kl_loss: 1.1015e-05 - loss: 0.9713 - recon_loss: 0.9713 - val_kl_loss: 0.0010 - val_loss: 0.7376 - val_recon_loss: 0.7365 - learning_rate: 1.2500e-05
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - kl_loss: 1.1300e-05 - loss: 0.9717 - recon_loss: 0.9717 - val_kl_loss: 0.0010 - val_loss: 0.7366 - val_recon_loss: 0.7356 - learning_rate: 1.2500e-05
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 230ms/step - kl_loss: 1.1023e-05 - loss: 0.9704 - recon_loss: 0.9704 - val_kl_loss: 0.0010 - val_loss: 0.7377 - val_recon_loss: 0.7367 - learning_rate: 1.2500e-05
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 234ms/step - kl_loss: 1.1033e-05 - loss: 0.9707 - recon_loss: 0.9707 - val_kl_loss: 0.0010 - val_loss: 0.7374 - val_recon_loss: 0.7363 - learning_rate: 1.2500e-05
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - kl_loss: 1.0786e-05 - loss: 0.9706 - recon_loss: 0.9706 - val_kl_loss: 0.0010 - val_loss: 0.7390 - val_recon_loss: 0.7380 - learning_rate: 6.2500e-06
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 205ms/step - kl_loss: 1.0647e-05 - loss: 0.9716 - recon_loss: 0.9716 - val_kl_loss: 0.0010 - val_loss: 0.7364 - val_recon_loss: 0.7354 - learning_rate: 6.2500e-06
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 264ms/step - kl_loss: 1.0617e-05 - loss: 0.9708 - recon_loss: 0.9708 - val_kl_loss: 0.0010 - val_loss: 0.7363 - val_recon_loss: 0.7353 - learning_rate: 6.2500e-06
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 200ms/step - kl_loss: 1.0549e-05 - loss: 0.9706 - recon_loss: 0.9706 - val_kl_loss: 0.0010 - val_loss: 0.7360 - val_recon_loss: 0.7349 - learning_rate: 6.2500e-06
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 209ms/step - kl_loss: 1.0499e-05 - loss: 0.9709 - recon_loss: 0.9709 - val_kl_loss: 0.0010 - val_loss: 0.7378 - val_recon_loss: 0.7368 - learning_rate: 6.2500e-06
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 244ms/step - kl_loss: 1.0506e-05 - loss: 0.9706 - recon_loss: 0.9706 - val_kl_loss: 0.0010 - val_loss: 0.7372 - val_recon_loss: 0.7362 - learning_rate: 6.2500e-06
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 205ms/step - kl_loss: 1.0353e-05 - loss: 0.9719 - recon_loss: 0.9719 - val_kl_loss: 0.0010 - val_loss: 0.7388 - val_recon_loss: 0.7377 - learning_rate: 6.2500e-06
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step - kl_loss: 1.0382e-05 - loss: 0.9704 - recon_loss: 0.9704 - val_kl_loss: 0.0010 - val_loss: 0.7379 - val_recon_loss: 0.7368 - learning_rate: 3.1250e-06
#
# ✓ CVAE training complete (epochs: 55)
# ✓ CVAE latent features: (683, 128)

# %%
# ========================================
# CELL 9: Build Multi-Modal VAE (Audio + Lyrics)
# ========================================
print("\n" + "="*60)
print("BUILDING MULTI-MODAL VAE")
print("="*60)

latent_dim_mm = 128

# Audio branch (spectrograms)
audio_input = keras.Input(shape=(spec_flat_normalized.shape[1],), name='audio_input')
x_audio = layers.Dense(1024, activation='relu')(audio_input)
x_audio = layers.BatchNormalization()(x_audio)
x_audio = layers.Dropout(0.3)(x_audio)
x_audio = layers.Dense(512, activation='relu')(x_audio)
x_audio = layers.BatchNormalization()(x_audio)
audio_encoded = layers.Dense(256, activation='relu')(x_audio)

# Lyrics branch
lyrics_input = keras.Input(shape=(lyrics_normalized.shape[1],), name='lyrics_input')
x_lyrics = layers.Dense(512, activation='relu')(lyrics_input)
x_lyrics = layers.BatchNormalization()(x_lyrics)
x_lyrics = layers.Dropout(0.3)(x_lyrics)
x_lyrics = layers.Dense(256, activation='relu')(x_lyrics)
x_lyrics = layers.BatchNormalization()(x_lyrics)
lyrics_encoded = layers.Dense(128, activation='relu')(x_lyrics)

# Fusion
fused = layers.Concatenate()([audio_encoded, lyrics_encoded])
x_fused = layers.Dense(512, activation='relu')(fused)
x_fused = layers.BatchNormalization()(x_fused)
x_fused = layers.Dropout(0.3)(x_fused)

z_mean_mm = layers.Dense(latent_dim_mm, name='z_mean_mm')(x_fused)
z_log_var_mm = layers.Dense(latent_dim_mm, name='z_log_var_mm')(x_fused)
z_mm = Sampling()([z_mean_mm, z_log_var_mm])

mm_encoder = Model([audio_input, lyrics_input],
                   [z_mean_mm, z_log_var_mm, z_mm],
                   name='multimodal_encoder')

# Decoder (reconstruct both modalities)
latent_input_mm = keras.Input(shape=(latent_dim_mm,))

# Audio decoder branch
x_audio_dec = layers.Dense(512, activation='relu')(latent_input_mm)
x_audio_dec = layers.BatchNormalization()(x_audio_dec)
x_audio_dec = layers.Dense(1024, activation='relu')(x_audio_dec)
x_audio_dec = layers.BatchNormalization()(x_audio_dec)
audio_output = layers.Dense(spec_flat_normalized.shape[1], activation='sigmoid', name='audio_output')(x_audio_dec)

# Lyrics decoder branch
x_lyrics_dec = layers.Dense(256, activation='relu')(latent_input_mm)
x_lyrics_dec = layers.BatchNormalization()(x_lyrics_dec)
x_lyrics_dec = layers.Dense(512, activation='relu')(x_lyrics_dec)
x_lyrics_dec = layers.BatchNormalization()(x_lyrics_dec)
lyrics_output = layers.Dense(lyrics_normalized.shape[1], activation='sigmoid', name='lyrics_output')(x_lyrics_dec)

mm_decoder = Model(latent_input_mm, [audio_output, lyrics_output], name='multimodal_decoder')

# Multi-Modal VAE
class MultiModalVAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.audio_recon_loss_tracker = keras.metrics.Mean(name="audio_recon_loss")
        self.lyrics_recon_loss_tracker = keras.metrics.Mean(name="lyrics_recon_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [self.total_loss_tracker, self.audio_recon_loss_tracker,
                self.lyrics_recon_loss_tracker, self.kl_loss_tracker]

    def train_step(self, data):
        # Correctly unpack the data for multi-modal VAE training
        (audio_input, lyrics_input), (audio_target, lyrics_target) = data

        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder([audio_input, lyrics_input])
            audio_recon, lyrics_recon = self.decoder(z)

            audio_recon_loss = tf.reduce_mean(tf.square(audio_target - audio_recon))
            lyrics_recon_loss = tf.reduce_mean(tf.square(lyrics_target - lyrics_recon))

            kl_loss = -0.5 * tf.reduce_mean(
                1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
            )

            total_loss = audio_recon_loss + lyrics_recon_loss + kl_loss

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        self.total_loss_tracker.update_state(total_loss)
        self.audio_recon_loss_tracker.update_state(audio_recon_loss)
        self.lyrics_recon_loss_tracker.update_state(lyrics_recon_loss)
        self.kl_loss_tracker.update_state(kl_loss)

        return {
            "loss": self.total_loss_tracker.result(),
            "audio_recon_loss": self.audio_recon_loss_tracker.result(),
            "lyrics_recon_loss": self.lyrics_recon_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data):
        # Correctly unpack the data for multi-modal VAE testing
        (audio_input, lyrics_input), (audio_target, lyrics_target) = data
        z_mean, z_log_var, z = self.encoder([audio_input, lyrics_input])
        audio_recon, lyrics_recon = self.decoder(z)

        audio_recon_loss = tf.reduce_mean(tf.square(audio_target - audio_recon))
        lyrics_recon_loss = tf.reduce_mean(tf.square(lyrics_target - lyrics_recon))
        kl_loss = -0.5 * tf.reduce_mean(
            1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
        )
        total_loss = audio_recon_loss + lyrics_recon_loss + kl_loss

        return {
            "loss": total_loss,
            "audio_recon_loss": audio_recon_loss,
            "lyrics_recon_loss": lyrics_recon_loss,
            "kl_loss": kl_loss
        }

mm_vae = MultiModalVAE(mm_encoder, mm_decoder)
mm_vae.compile(optimizer=keras.optimizers.Adam(1e-4))

print(f"✓ Multi-Modal VAE built with latent_dim={latent_dim_mm}")

print("\n✓ All models built successfully!")
print(f"  1. Beta-VAE (beta={beta})")
print(f"  2. CVAE (conditional)" if cvae else "  2. CVAE (skipped - no labels)")
print(f"  3. Multi-Modal VAE (audio + lyrics)")
# Out:
# ============================================================
# BUILDING MULTI-MODAL VAE
# ============================================================
# ✓ Multi-Modal VAE built with latent_dim=128
#
# ✓ All models built successfully!
#   1. Beta-VAE (beta=4.0)
#   2. CVAE (conditional)
#   3. Multi-Modal VAE (audio + lyrics)

# %%
# ========================================
# CELL 9A: Train Multi-Modal VAE
# ========================================
print("\n" + "="*60)
print("TRAINING MULTI-MODAL VAE")
print("="*60)

early_stopping_mm = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True
)

lr_schedule_mm = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=7,
    min_lr=1e-6
)

# Split data for training and validation
from sklearn.model_selection import train_test_split

(train_spec_mm, val_spec_mm, train_lyrics_mm, val_lyrics_mm) = train_test_split(
    spec_flat_normalized, lyrics_normalized, test_size=0.2, random_state=42
)

# The train_step for MultiModalVAE expects (audio_input, lyrics_input), (audio_target, lyrics_target)
# So we need to create a dataset that yields tuples of tuples.

history_mm = mm_vae.fit(
    x=(train_spec_mm, train_lyrics_mm),
    y=(train_spec_mm, train_lyrics_mm), # VAE's target is its input
    epochs=120,
    batch_size=32,
    validation_data=((val_spec_mm, val_lyrics_mm), (val_spec_mm, val_lyrics_mm)),
    callbacks=[early_stopping_mm, lr_schedule_mm],
    verbose=1
)

print(f"\n✓ Multi-Modal VAE training complete (epochs: {len(history_mm.history['loss'])})")

# Plot training
plt.figure(figsize=(18, 5))
plt.subplot(1, 4, 1)
plt.plot(history_mm.history['loss'], label='Train', linewidth=2)
plt.plot(history_mm.history['val_loss'], label='Val', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Total Loss')
plt.legend()
plt.title('Multi-Modal VAE Total Loss')
plt.grid(True, alpha=0.3)

plt.subplot(1, 4, 2)
plt.plot(history_mm.history['audio_recon_loss'], label='Train', linewidth=2)
plt.plot(history_mm.history['val_audio_recon_loss'], label='Val', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Audio Recon Loss')
plt.legend()
plt.title('MM VAE Audio Reconstruction')
plt.grid(True, alpha=0.3)

plt.subplot(1, 4, 3)
plt.plot(history_mm.history['lyrics_recon_loss'], label='Train', linewidth=2)
plt.plot(history_mm.history['val_lyrics_recon_loss'], label='Val', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Lyrics Recon Loss')
plt.legend()
plt.title('MM VAE Lyrics Reconstruction')
plt.grid(True, alpha=0.3)

plt.subplot(1, 4, 4)
plt.plot(history_mm.history['kl_loss'], label='Train', linewidth=2)
plt.plot(history_mm.history['val_kl_loss'], label='Val', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('KL Loss')
plt.legend()
plt.title('MM VAE KL Divergence')
plt.grid(True, alpha=0.3)

plt.tight_layout()
output_dir_mm_vis = os.path.join(base_path, 'visualizations')
os.makedirs(output_dir_mm_vis, exist_ok=True)
plt.savefig(os.path.join(output_dir_mm_vis, 'mm_vae_training.png'), dpi=300, bbox_inches='tight')
plt.show()

# Extract latent features AFTER training
z_mean_mm_features, _, _ = mm_encoder.predict([spec_flat_normalized, lyrics_normalized], verbose=0)
print(f"✓ Multi-Modal VAE latent features: {z_mean_mm_features.shape}")


# ========================================
# CELL 10: Comprehensive Clustering
# ========================================
print("\n" + "="*60)
print("COMPREHENSIVE CLUSTERING EVALUATION")
print("="*60)

def evaluate_clustering(features, clusters, method_name, true_labels=None):
    """Comprehensive clustering evaluation"""

    # Skip if only one cluster (e.g., all noise for DBSCAN, or only 1 cluster found)
    # Check number of unique *valid* clusters for the initial skip logic
    valid_cluster_ids = np.unique(clusters[clusters >= 0])
    if len(valid_cluster_ids) < 2:
        print(f"\n{method_name}: Less than 2 valid clusters found (unique_ids={len(valid_cluster_ids)}) - skipping metrics")
        return None

    # Basic metrics - these handle -1 (noise) correctly by ignoring them
    silhouette = silhouette_score(features, clusters)
    davies_bouldin = davies_bouldin_score(features, clusters)
    calinski = calinski_harabasz_score(features, clusters)

    # Cluster balance - filter out noise points for bincount
    valid_clusters = clusters[clusters >= 0]
    if len(valid_clusters) == 0: # All points are noise
        print(f"\n{method_name}: All points assigned as noise by DBSCAN - skipping balance metrics")
        return None # Return None if no valid clusters exist for balance calculation

    cluster_sizes = np.bincount(valid_clusters) # Only count positive cluster IDs
    balance_ratio = cluster_sizes.min() / cluster_sizes.max()

    # Label-based metrics (if available)
    if true_labels is not None:
        # NMI and ARI handle -1 (noise) correctly by ignoring them
        nmi = normalized_mutual_info_score(true_labels, clusters)
        ari = adjusted_rand_score(true_labels, clusters)

        # Cluster purity: calculated only for non-noise points
        total_correctly_classified = 0
        non_noise_indices = (clusters != -1)
        if non_noise_indices.sum() > 0:
            for cluster_id in np.unique(clusters[non_noise_indices]):
                # Find true labels for points in this cluster (excluding noise)
                cluster_true_labels = true_labels[clusters == cluster_id]
                if len(cluster_true_labels) > 0:
                    # Find the most frequent true label in this cluster
                    most_common_label_count = np.bincount(cluster_true_labels).max()
                    total_correctly_classified += most_common_label_count
            purity = total_correctly_classified / non_noise_indices.sum()
        else: # All points are noise or no points assigned to valid clusters
            purity = 0.0
    else:
        nmi = None
        ari = None
        purity = None

    results = {
        'method': method_name,
        'silhouette': silhouette,
        'davies_bouldin': davies_bouldin,
        'calinski': calinski,
        'balance_ratio': balance_ratio,
        'cluster_sizes': cluster_sizes,
        'nmi': nmi,
        'ari': ari,
        'purity': purity
    }

    return results

# Prepare baseline (PCA + Autoencoder)
print("\n1. Preparing Baselines...")

# PCA
pca = PCA(n_components=128)
pca_features = pca.fit_transform(spec_flat_normalized)
print(f"   PCA features: {pca_features.shape}, Explained variance: {pca.explained_variance_ratio_.sum():.4f}")

# Simple Autoencoder
ae_input = keras.Input(shape=(spec_flat_normalized.shape[1],))
ae_encoded = layers.Dense(1024, activation='relu')(ae_input)
ae_encoded = layers.Dense(512, activation='relu')(ae_encoded)
ae_encoded = layers.Dense(128, activation='relu')(ae_encoded)

ae_decoded = layers.Dense(512, activation='relu')(ae_encoded)
ae_decoded = layers.Dense(1024, activation='relu')(ae_decoded)
ae_decoded = layers.Dense(spec_flat_normalized.shape[1], activation='sigmoid')(ae_decoded)

autoencoder = Model(ae_input, ae_decoded)
encoder_ae = Model(ae_input, ae_encoded)

autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.fit(spec_flat_normalized, spec_flat_normalized,
                epochs=50, batch_size=32, validation_split=0.2, verbose=0)

ae_features = encoder_ae.predict(spec_flat_normalized, verbose=0)
print(f"   Autoencoder features: {ae_features.shape}")

# Direct spectral features (flattened spectrograms with PCA for dimensionality)
spectral_pca = PCA(n_components=128)
spectral_features = spectral_pca.fit_transform(spec_flat_normalized)
print(f"   Spectral features: {spectral_features.shape}")

# Collect all feature sets
feature_sets = {
    'Beta-VAE': z_mean_beta_features,
    'Multi-Modal VAE': z_mean_mm_features,
    'PCA': pca_features,
    'Autoencoder': ae_features,
    'Spectral': spectral_features
}

if z_mean_cvae_features is not None:
    feature_sets['CVAE'] = z_mean_cvae_features

# Clustering algorithms
print("\n2. Testing Multiple Clustering Algorithms...")

clustering_algorithms = {
    'K-Means': lambda k: KMeans(n_clusters=k, random_state=42, n_init=10),
    'Agglomerative': lambda k: AgglomerativeClustering(n_clusters=k, linkage='ward'),
    'DBSCAN': lambda k: DBSCAN(eps=0.5, min_samples=5)
}

# Determine optimal k
optimal_k = 5  # Default
if has_labels:
    optimal_k = n_classes
    print(f"   Using k={optimal_k} (from labels)")
else:
    # Try to find optimal k using elbow method
    print("   Finding optimal k using silhouette scores...")
    sil_scores = []
    k_range = range(3, 11)
    for k in k_range:
        kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
        clusters = kmeans.fit_predict(z_mean_mm_features)
        # Ensure there are at least 2 unique labels (excluding -1) for silhouette score
        if len(np.unique(clusters[clusters >= 0])) > 1:
            sil = silhouette_score(z_mean_mm_features, clusters)
            sil_scores.append(sil)
        else:
            sil_scores.append(-1) # Assign a low score if not enough clusters

    # Check if any valid silhouette scores were found
    if max(sil_scores) > -1:
        optimal_k = list(k_range)[np.argmax(sil_scores)]
        print(f"   Optimal k={optimal_k} (silhouette: {max(sil_scores):.4f})")
    else:
        print("   Could not determine optimal k using silhouette (not enough clusters found).")
        optimal_k = 3 # Fallback to a default k

# Perform clustering and evaluation
all_results = []

for feat_name, features in feature_sets.items():
    print(f"\n{'='*60}")
    print(f"Feature Set: {feat_name}")
    print(f"{'='*60}")

    for algo_name, algo_func in clustering_algorithms.items():
        print(f"\n  Algorithm: {algo_name}")

        # Perform clustering
        if algo_name == 'DBSCAN':
            algo = algo_func(None)
            clusters = algo.fit_predict(features)
        else:
            algo = algo_func(optimal_k)
            clusters = algo.fit_predict(features)

        # Evaluate
        true_labels_eval = labels_encoded if has_labels else None
        results = evaluate_clustering(features, clusters,
                                      f"{feat_name} + {algo_name}",
                                      true_labels_eval)

        if results:
            all_results.append(results)

            print(f"    Silhouette: {results['silhouette']:.4f}")
            print(f"    Davies-Bouldin: {results['davies_bouldin']:.4f}")
            print(f"    Calinski-Harabasz: {results['calinski']:.2f}")
            print(f"    Balance Ratio: {results['balance_ratio']:.3f}")
            # Print cluster sizes as string since it's an array
            print(f"    Cluster Sizes: {results['cluster_sizes'].tolist()}")

            if results['nmi'] is not None:
                print(f"    NMI: {results['nmi']:.4f}")
                print(f"    ARI: {results['ari']:.4f}")
                print(f"    Purity: {results['purity']:.4f}")
# Out:
# ============================================================
# TRAINING MULTI-MODAL VAE
# ============================================================
# Epoch 1/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 24s 437ms/step - audio_recon_loss: 1.1576 - kl_loss: 0.1078 - loss: 2.5061 - lyrics_recon_loss: 1.2407 - val_audio_recon_loss: 0.8517 - val_kl_loss: 0.0215 - val_loss: 2.1701 - val_lyrics_recon_loss: 1.2970 - learning_rate: 1.0000e-04
# Epoch 2/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - audio_recon_loss: 1.1369 - kl_loss: 0.0182 - loss: 2.3491 - lyrics_recon_loss: 1.1939 - val_audio_recon_loss: 0.7641 - val_kl_loss: 0.0149 - val_loss: 2.0301 - val_lyrics_recon_loss: 1.2512 - learning_rate: 1.0000e-04
# Epoch 3/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - audio_recon_loss: 0.9842 - kl_loss: 0.0213 - loss: 2.1450 - lyrics_recon_loss: 1.1396 - val_audio_recon_loss: 0.7329 - val_kl_loss: 0.0149 - val_loss: 1.9423 - val_lyrics_recon_loss: 1.1945 - learning_rate: 1.0000e-04
# Epoch 4/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - audio_recon_loss: 0.9757 - kl_loss: 0.0210 - loss: 2.0816 - lyrics_recon_loss: 1.0848 - val_audio_recon_loss: 0.7261 - val_kl_loss: 0.0112 - val_loss: 1.8885 - val_lyrics_recon_loss: 1.1512 - learning_rate: 1.0000e-04
# Epoch 5/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - audio_recon_loss: 0.9822 - kl_loss: 0.0148 - loss: 2.0419 - lyrics_recon_loss: 1.0450 - val_audio_recon_loss: 0.7307 - val_kl_loss: 0.0110 - val_loss: 1.8647 - val_lyrics_recon_loss: 1.1231 - learning_rate: 1.0000e-04
# Epoch 6/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - audio_recon_loss: 0.9549 - kl_loss: 0.0128 - loss: 1.9844 - lyrics_recon_loss: 1.0167 - val_audio_recon_loss: 0.7282 - val_kl_loss: 0.0094 - val_loss: 1.8537 - val_lyrics_recon_loss: 1.1161 - learning_rate: 1.0000e-04
# Epoch 7/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - audio_recon_loss: 0.9762 - kl_loss: 0.0128 - loss: 1.9993 - lyrics_recon_loss: 1.0104 - val_audio_recon_loss: 0.7253 - val_kl_loss: 0.0084 - val_loss: 1.8377 - val_lyrics_recon_loss: 1.1040 - learning_rate: 1.0000e-04
# Epoch 8/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - audio_recon_loss: 0.9506 - kl_loss: 0.0140 - loss: 1.9654 - lyrics_recon_loss: 1.0008 - val_audio_recon_loss: 0.7225 - val_kl_loss: 0.0101 - val_loss: 1.8331 - val_lyrics_recon_loss: 1.1005 - learning_rate: 1.0000e-04
# Epoch 9/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - audio_recon_loss: 0.9254 - kl_loss: 0.0205 - loss: 1.9629 - lyrics_recon_loss: 1.0170 - val_audio_recon_loss: 0.7147 - val_kl_loss: 0.0141 - val_loss: 1.8310 - val_lyrics_recon_loss: 1.1022 - learning_rate: 1.0000e-04
# Epoch 10/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - audio_recon_loss: 0.9294 - kl_loss: 0.0268 - loss: 1.9632 - lyrics_recon_loss: 1.0071 - val_audio_recon_loss: 0.7170 - val_kl_loss: 0.0173 - val_loss: 1.8352 - val_lyrics_recon_loss: 1.1009 - learning_rate: 1.0000e-04
# Epoch 11/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - audio_recon_loss: 0.8910 - kl_loss: 0.0325 - loss: 1.9342 - lyrics_recon_loss: 1.0106 - val_audio_recon_loss: 0.7082 - val_kl_loss: 0.0164 - val_loss: 1.8232 - val_lyrics_recon_loss: 1.0987 - learning_rate: 1.0000e-04
# Epoch 12/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - audio_recon_loss: 0.9037 - kl_loss: 0.0320 - loss: 1.9367 - lyrics_recon_loss: 1.0010 - val_audio_recon_loss: 0.7161 - val_kl_loss: 0.0161 - val_loss: 1.8307 - val_lyrics_recon_loss: 1.0985 - learning_rate: 1.0000e-04
# Epoch 13/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - audio_recon_loss: 0.9256 - kl_loss: 0.0322 - loss: 1.9667 - lyrics_recon_loss: 1.0089 - val_audio_recon_loss: 0.7155 - val_kl_loss: 0.0168 - val_loss: 1.8310 - val_lyrics_recon_loss: 1.0987 - learning_rate: 1.0000e-04
# Epoch 14/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - audio_recon_loss: 0.8830 - kl_loss: 0.0310 - loss: 1.9002 - lyrics_recon_loss: 0.9861 - val_audio_recon_loss: 0.7037 - val_kl_loss: 0.0150 - val_loss: 1.8164 - val_lyrics_recon_loss: 1.0978 - learning_rate: 1.0000e-04
# Epoch 15/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - audio_recon_loss: 0.8384 - kl_loss: 0.0292 - loss: 1.8723 - lyrics_recon_loss: 1.0047 - val_audio_recon_loss: 0.7014 - val_kl_loss: 0.0141 - val_loss: 1.8123 - val_lyrics_recon_loss: 1.0968 - learning_rate: 1.0000e-04
# Epoch 16/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - audio_recon_loss: 0.8768 - kl_loss: 0.0279 - loss: 1.9054 - lyrics_recon_loss: 1.0007 - val_audio_recon_loss: 0.7069 - val_kl_loss: 0.0091 - val_loss: 1.8129 - val_lyrics_recon_loss: 1.0970 - learning_rate: 1.0000e-04
# Epoch 17/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - audio_recon_loss: 0.9208 - kl_loss: 0.0231 - loss: 1.9469 - lyrics_recon_loss: 1.0031 - val_audio_recon_loss: 0.7093 - val_kl_loss: 0.0084 - val_loss: 1.8147 - val_lyrics_recon_loss: 1.0970 - learning_rate: 1.0000e-04
# Epoch 18/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - audio_recon_loss: 0.9130 - kl_loss: 0.0212 - loss: 1.9327 - lyrics_recon_loss: 0.9984 - val_audio_recon_loss: 0.7008 - val_kl_loss: 0.0100 - val_loss: 1.8074 - val_lyrics_recon_loss: 1.0966 - learning_rate: 1.0000e-04
# Epoch 19/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - audio_recon_loss: 0.8604 - kl_loss: 0.0235 - loss: 1.8761 - lyrics_recon_loss: 0.9922 - val_audio_recon_loss: 0.7102 - val_kl_loss: 0.0119 - val_loss: 1.8199 - val_lyrics_recon_loss: 1.0978 - learning_rate: 1.0000e-04
# Epoch 20/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - audio_recon_loss: 0.8610 - kl_loss: 0.0282 - loss: 1.9005 - lyrics_recon_loss: 1.0112 - val_audio_recon_loss: 0.7073 - val_kl_loss: 0.0122 - val_loss: 1.8170 - val_lyrics_recon_loss: 1.0976 - learning_rate: 1.0000e-04
# Epoch 21/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - audio_recon_loss: 0.8862 - kl_loss: 0.0235 - loss: 1.9016 - lyrics_recon_loss: 0.9919 - val_audio_recon_loss: 0.7391 - val_kl_loss: 0.0097 - val_loss: 1.8465 - val_lyrics_recon_loss: 1.0976 - learning_rate: 1.0000e-04
# Epoch 22/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - audio_recon_loss: 0.8441 - kl_loss: 0.0197 - loss: 1.8597 - lyrics_recon_loss: 0.9960 - val_audio_recon_loss: 0.7191 - val_kl_loss: 0.0095 - val_loss: 1.8250 - val_lyrics_recon_loss: 1.0964 - learning_rate: 1.0000e-04
# Epoch 23/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - audio_recon_loss: 0.9322 - kl_loss: 0.0243 - loss: 1.9548 - lyrics_recon_loss: 0.9984 - val_audio_recon_loss: 0.7230 - val_kl_loss: 0.0099 - val_loss: 1.8301 - val_lyrics_recon_loss: 1.0972 - learning_rate: 1.0000e-04
# Epoch 24/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - audio_recon_loss: 0.8619 - kl_loss: 0.0201 - loss: 1.8705 - lyrics_recon_loss: 0.9885 - val_audio_recon_loss: 0.7150 - val_kl_loss: 0.0090 - val_loss: 1.8212 - val_lyrics_recon_loss: 1.0972 - learning_rate: 1.0000e-04
# Epoch 25/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - audio_recon_loss: 0.8386 - kl_loss: 0.0194 - loss: 1.8565 - lyrics_recon_loss: 0.9986 - val_audio_recon_loss: 0.7253 - val_kl_loss: 0.0084 - val_loss: 1.8310 - val_lyrics_recon_loss: 1.0973 - learning_rate: 1.0000e-04
# Epoch 26/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - audio_recon_loss: 0.8230 - kl_loss: 0.0171 - loss: 1.8252 - lyrics_recon_loss: 0.9851 - val_audio_recon_loss: 0.7111 - val_kl_loss: 0.0068 - val_loss: 1.8146 - val_lyrics_recon_loss: 1.0967 - learning_rate: 5.0000e-05
# Epoch 27/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - audio_recon_loss: 0.8642 - kl_loss: 0.0167 - loss: 1.8872 - lyrics_recon_loss: 1.0062 - val_audio_recon_loss: 0.7347 - val_kl_loss: 0.0066 - val_loss: 1.8382 - val_lyrics_recon_loss: 1.0969 - learning_rate: 5.0000e-05
# Epoch 28/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - audio_recon_loss: 0.8605 - kl_loss: 0.0177 - loss: 1.8724 - lyrics_recon_loss: 0.9942 - val_audio_recon_loss: 0.7167 - val_kl_loss: 0.0072 - val_loss: 1.8208 - val_lyrics_recon_loss: 1.0969 - learning_rate: 5.0000e-05
# Epoch 29/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - audio_recon_loss: 0.8636 - kl_loss: 0.0194 - loss: 1.8866 - lyrics_recon_loss: 1.0035 - val_audio_recon_loss: 0.7192 - val_kl_loss: 0.0069 - val_loss: 1.8234 - val_lyrics_recon_loss: 1.0973 - learning_rate: 5.0000e-05
# Epoch 30/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - audio_recon_loss: 0.8494 - kl_loss: 0.0160 - loss: 1.8661 - lyrics_recon_loss: 1.0007 - val_audio_recon_loss: 0.7068 - val_kl_loss: 0.0059 - val_loss: 1.8098 - val_lyrics_recon_loss: 1.0970 - learning_rate: 5.0000e-05
# Epoch 31/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - audio_recon_loss: 0.8345 - kl_loss: 0.0155 - loss: 1.8573 - lyrics_recon_loss: 1.0073 - val_audio_recon_loss: 0.7134 - val_kl_loss: 0.0075 - val_loss: 1.8178 - val_lyrics_recon_loss: 1.0969 - learning_rate: 5.0000e-05
# Epoch 32/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - audio_recon_loss: 0.8576 - kl_loss: 0.0243 - loss: 1.8826 - lyrics_recon_loss: 1.0006 - val_audio_recon_loss: 0.7183 - val_kl_loss: 0.0063 - val_loss: 1.8212 - val_lyrics_recon_loss: 1.0966 - learning_rate: 5.0000e-05
# Epoch 33/120
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - audio_recon_loss: 0.8784 - kl_loss: 0.0186 - loss: 1.8799 - lyrics_recon_loss: 0.9829 - val_audio_recon_loss: 0.7079 - val_kl_loss: 0.0062 - val_loss: 1.8106 - val_lyrics_recon_loss: 1.0966 - learning_rate: 2.5000e-05
#
# ✓ Multi-Modal VAE training complete (epochs: 33)
# ✓ Multi-Modal VAE latent features: (683, 128)
#
# ============================================================
# COMPREHENSIVE CLUSTERING EVALUATION
# ============================================================
#
# 1. Preparing Baselines...
#    PCA features: (683, 128), Explained variance: 0.7420
#    Autoencoder features: (683, 128)
#    Spectral features: (683, 128)
#
# 2. Testing Multiple Clustering Algorithms...
#    Using k=5 (from labels)
#
# ============================================================
# Feature Set: Beta-VAE
# ============================================================
#
#   Algorithm: K-Means
#     Silhouette: 0.9129
#     Davies-Bouldin: 0.0482
#     Calinski-Harabasz: 50.11
#     Balance Ratio: 0.001
#     Cluster Sizes: [679, 1, 1, 1, 1]
#     NMI: 0.0099
#     ARI: -0.0012
#     Purity: 0.2665
#
#   Algorithm: Agglomerative
#     Silhouette: 0.9011
#     Davies-Bouldin: 1.8124
#     Calinski-Harabasz: 60.04
#     Balance Ratio: 0.002
#     Cluster Sizes: [4, 11, 4, 663, 1]
#     NMI: 0.0473
#     ARI: -0.0040
#     Purity: 0.2899
#
#   Algorithm: DBSCAN
#
# Beta-VAE + DBSCAN: Less than 2 valid clusters found (unique_ids=1) - skipping metrics
#
# ============================================================
# Feature Set: Multi-Modal VAE
# ============================================================
#
#   Algorithm: K-Means
#     Silhouette: 0.3935
#     Davies-Bouldin: 0.8162
#     Calinski-Harabasz: 1580.12
#     Balance Ratio: 0.351
#     Cluster Sizes: [106, 248, 115, 87, 127]
#     NMI: 0.0434
#     ARI: 0.0296
#     Purity: 0.3587
#
#   Algorithm: Agglomerative
#     Silhouette: 0.3699
#     Davies-Bouldin: 0.8211
#     Calinski-Harabasz: 1469.51
#     Balance Ratio: 0.269
#     Cluster Sizes: [145, 264, 119, 71, 84]
#     NMI: 0.0400
#     ARI: 0.0350
#     Purity: 0.3646
#
#   Algorithm: DBSCAN
#     Silhouette: -0.0145
#     Davies-Bouldin: 2.6115
#     Calinski-Harabasz: 175.19
#     Balance Ratio: 0.020
#     Cluster Sizes: [253, 114, 5]
#     NMI: 0.0361
#     ARI: 0.0217
#     Purity: 0.4005
#
# ============================================================
# Feature Set: PCA
# ============================================================
#
#   Algorithm: K-Means
#     Silhouette: 0.0822
#     Davies-Bouldin: 2.3741
#     Calinski-Harabasz: 118.63
#     Balance Ratio: 0.345
#     Cluster Sizes: [136, 132, 119, 220, 76]
#     NMI: 0.0857
#     ARI: 0.0661
#     Purity: 0.3880
#
#   Algorithm: Agglomerative
#     Silhouette: 0.0603
#     Davies-Bouldin: 2.4129
#     Calinski-Harabasz: 107.18
#     Balance Ratio: 0.177
#     Cluster Sizes: [168, 198, 35, 168, 114]
#     NMI: 0.0789
#     ARI: 0.0686
#     Purity: 0.3968
#
#   Algorithm: DBSCAN
#
# PCA + DBSCAN: Less than 2 valid clusters found (unique_ids=0) - skipping metrics
#
# ============================================================
# Feature Set: Autoencoder
# ============================================================
#
#   Algorithm: K-Means
#     Silhouette: 0.2548
#     Davies-Bouldin: 1.3962
#     Calinski-Harabasz: 576.18
#     Balance Ratio: 0.026
#     Cluster Sizes: [86, 128, 42, 416, 11]
#     NMI: 0.0154
#     ARI: 0.0165
#     Purity: 0.3148
#
#   Algorithm: Agglomerative
#     Silhouette: 0.2119
#     Davies-Bouldin: 1.5474
#     Calinski-Harabasz: 538.78
#     Balance Ratio: 0.058
#     Cluster Sizes: [27, 414, 96, 24, 122]
#     NMI: 0.0212
#     ARI: 0.0190
#     Purity: 0.3265
#
#   Algorithm: DBSCAN
#
# Autoencoder + DBSCAN: Less than 2 valid clusters found (unique_ids=0) - skipping metrics
#
# ============================================================
# Feature Set: Spectral
# ============================================================
#
#   Algorithm: K-Means
#     Silhouette: 0.0824
#     Davies-Bouldin: 2.3659
#     Calinski-Harabasz: 118.65
#     Balance Ratio: 0.336
#     Cluster Sizes: [76, 119, 226, 123, 139]
#     NMI: 0.0879
#     ARI: 0.0669
#     Purity: 0.3880
#
#   Algorithm: Agglomerative
#     Silhouette: 0.1064
#     Davies-Bouldin: 2.5280
#     Calinski-Harabasz: 106.77
#     Balance Ratio: 0.143
#     Cluster Sizes: [314, 45, 200, 64, 60]
#     NMI: 0.0468
#     ARI: 0.0268
#     Purity: 0.3616
#
#   Algorithm: DBSCAN
#
# Spectral + DBSCAN: Less than 2 valid clusters found (unique_ids=0) - skipping metrics
#
# ============================================================
# Feature Set: CVAE
# ============================================================
#
#   Algorithm: K-Means
#     Silhouette: 0.9476
#     Davies-Bouldin: 0.0289
#     Calinski-Harabasz: 86.04
#     Balance Ratio: 0.001
#     Cluster Sizes: [679, 1, 1, 1, 1]
#     NMI: 0.0102
#     ARI: -0.0009
#     Purity: 0.2650
#
#   Algorithm: Agglomerative
#     Silhouette: 0.9352
#     Davies-Bouldin: 1.1816
#     Calinski-Harabasz: 102.61
#     Balance Ratio: 0.001
#     Cluster Sizes: [3, 6, 671, 1, 2]
#     NMI: 0.0105
#     ARI: -0.0008
#     Purity: 0.2665
#
#   Algorithm: DBSCAN
#
# CVAE + DBSCAN: Less than 2 valid clusters found (unique_ids=1) - skipping metrics

# %%
# ========================================
# CELL 10: Results Summary
# ========================================
print("\n" + "="*60)
print("COMPREHENSIVE RESULTS SUMMARY")
print("="*60)

# Create results DataFrame
results_df = pd.DataFrame(all_results)

# Display full results
print("\n" + results_df.to_string(index=False))

# Save results
metrics_output_dir = os.path.join(base_path, 'metrics')
os.makedirs(metrics_output_dir, exist_ok=True)
results_df.to_csv(os.path.join(metrics_output_dir, 'hard_task_comprehensive_metrics.csv'), index=False)
print(f"\n✓ Results saved to: {os.path.join(metrics_output_dir, 'hard_task_comprehensive_metrics.csv')}")

# Find best methods
print("\n" + "="*60)
print("BEST PERFORMING METHODS")
print("="*60)

# Best by Silhouette
best_sil = results_df.loc[results_df['silhouette'].idxmax()]
print(f"\nBest Silhouette Score:")
print(f"  Method: {best_sil['method']}")
print(f"  Score: {best_sil['silhouette']:.4f}")
print(f"  Balance: {best_sil['balance_ratio']:.3f}")

# Best by Davies-Bouldin (lower is better)
best_db = results_df.loc[results_df['davies_bouldin'].idxmin()]
print(f"\nBest Davies-Bouldin Index:")
print(f"  Method: {best_db['method']}")
print(f"  Score: {best_db['davies_bouldin']:.4f}")
print(f"  Balance: {best_db['balance_ratio']:.3f}")

if has_labels:
    # Best by NMI
    best_nmi = results_df.loc[results_df['nmi'].idxmax()]
    print(f"\nBest NMI:")
    print(f"  Method: {best_nmi['method']}")
    print(f"  NMI: {best_nmi['nmi']:.4f}")
    print(f"  ARI: {best_nmi['ari']:.4f}")
    print(f"  Purity: {best_nmi['purity']:.4f}")
# Out:
# ============================================================
# COMPREHENSIVE RESULTS SUMMARY
# ============================================================
#
#                          method  silhouette  davies_bouldin    calinski  balance_ratio            cluster_sizes      nmi       ari   purity
#              Beta-VAE + K-Means    0.912949        0.048179   50.106583       0.001473        [679, 1, 1, 1, 1] 0.009925 -0.001162 0.266471
#        Beta-VAE + Agglomerative    0.901112        1.812355   60.042736       0.001508       [4, 11, 4, 663, 1] 0.047331 -0.003978 0.289898
#       Multi-Modal VAE + K-Means    0.393509        0.816250 1580.122803       0.350806 [106, 248, 115, 87, 127] 0.043405  0.029644 0.358712
# Multi-Modal VAE + Agglomerative    0.369948        0.821070 1469.510376       0.268939  [145, 264, 119, 71, 84] 0.039959  0.034994 0.364568
#        Multi-Modal VAE + DBSCAN   -0.014536        2.611453  175.190704       0.019763            [253, 114, 5] 0.036113  0.021654 0.400538
#                   PCA + K-Means    0.082248        2.374091  118.632919       0.345455 [136, 132, 119, 220, 76] 0.085676  0.066133 0.387994
#             PCA + Agglomerative    0.060251        2.412908  107.178925       0.176768 [168, 198, 35, 168, 114] 0.078932  0.068575 0.396779
#           Autoencoder + K-Means    0.254819        1.396195  576.180786       0.026442   [86, 128, 42, 416, 11] 0.015427  0.016458 0.314788
#     Autoencoder + Agglomerative    0.211883        1.547388  538.780090       0.057971   [27, 414, 96, 24, 122] 0.021192  0.018984 0.326501
#              Spectral + K-Means    0.082367        2.365912  118.646820       0.336283 [76, 119, 226, 123, 139] 0.087871  0.066866 0.387994
#        Spectral + Agglomerative    0.106435        2.527962  106.768318       0.143312   [314, 45, 200, 64, 60] 0.046832  0.026765 0.361640
#                  CVAE + K-Means    0.947564        0.028872   86.037201       0.001473        [679, 1, 1, 1, 1] 0.010152 -0.000941 0.265007
#            CVAE + Agglomerative    0.935195        1.181553  102.614418       0.001490        [3, 6, 671, 1, 2] 0.010516 -0.000824 0.266471
#
# ✓ Results saved to: /content/drive/MyDrive/VAE for Hybrid Language Music Clustering/metrics/hard_task_comprehensive_metrics.csv
#
# ============================================================
# BEST PERFORMING METHODS
# ============================================================
#
# Best Silhouette Score:
#   Method: CVAE + K-Means
#   Score: 0.9476
#   Balance: 0.001
#
# Best Davies-Bouldin Index:
#   Method: CVAE + K-Means
#   Score: 0.0289
#   Balance: 0.001
#
# Best NMI:
#   Method: Spectral + K-Means
#   NMI: 0.0879
#   ARI: 0.0669
#   Purity: 0.3880

# %%
# ========================================
# CELL 11: Visualization - Metrics Comparison
# ========================================
print("\n" + "="*60)
print("GENERATING VISUALIZATIONS")
print("="*60)

# Metrics comparison heatmap
fig, axes = plt.subplots(2, 2, figsize=(18, 14))

# Prepare data for plotting
plot_methods = results_df['method'].values
metrics_to_plot = ['silhouette', 'davies_bouldin', 'calinski', 'balance_ratio']
metric_labels = ['Silhouette\n(higher better)', 'Davies-Bouldin\n(lower better)',
                 'Calinski-Harabasz\n(higher better)', 'Balance Ratio\n(higher better)']

for idx, (metric, label) in enumerate(zip(metrics_to_plot, metric_labels)):
    ax = axes[idx // 2, idx % 2]

    # Group by feature set
    feature_sets_plot = []
    for method in plot_methods:
        feature_sets_plot.append(method.split(' + ')[0])

    unique_features = list(dict.fromkeys(feature_sets_plot))

    # Create grouped bar chart
    x = np.arange(len(unique_features))
    width = 0.25

    algo_names = list(clustering_algorithms.keys())
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c']

    for i, algo in enumerate(algo_names):
        values = []
        for feat in unique_features:
            matching = results_df[results_df['method'] == f"{feat} + {algo}"]
            if len(matching) > 0:
                values.append(matching[metric].values[0])
            else:
                values.append(0)

        ax.bar(x + i*width, values, width, label=algo, color=colors[i], alpha=0.8)

    ax.set_xlabel('Feature Set', fontsize=11, fontweight='bold')
    ax.set_ylabel(label, fontsize=11, fontweight='bold')
    ax.set_title(f'{label.split()[0]} Comparison', fontsize=13, fontweight='bold')
    ax.set_xticks(x + width)
    ax.set_xticklabels(unique_features, rotation=45, ha='right')
    ax.legend(fontsize=9)
    ax.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
visualizations_output_dir = os.path.join(base_path, 'visualizations')
os.makedirs(visualizations_output_dir, exist_ok=True)
plt.savefig(os.path.join(visualizations_output_dir, 'metrics_comparison_hard.png'), dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ============================================================
# GENERATING VISUALIZATIONS
# ============================================================

# %%
# ========================================
# CELL 12: Latent Space Visualizations
# ========================================
print("\nGenerating latent space visualizations...")

# Select best method from each VAE type for visualization
vae_methods = {
    'Beta-VAE': z_mean_beta_features,
    'Multi-Modal VAE': z_mean_mm_features
}

if z_mean_cvae_features is not None:
    vae_methods['CVAE'] = z_mean_cvae_features

# Get clusters for each
vae_clusters_dict = {}
for name, features in vae_methods.items():
    kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
    vae_clusters_dict[name] = kmeans.fit_predict(features)

# Create comprehensive visualization
fig, axes = plt.subplots(len(vae_methods), 2, figsize=(16, 6*len(vae_methods)))

if len(vae_methods) == 1:
    axes = axes.reshape(1, -1)

for idx, (name, features) in enumerate(vae_methods.items()):
    clusters = vae_clusters_dict[name]

    # Get metrics for title
    method_results = results_df[results_df['method'] == f"{name} + K-Means"]
    if len(method_results) > 0:
        sil = method_results['silhouette'].values[0]
        db = method_results['davies_bouldin'].values[0]
    else:
        sil, db = 0, 0

    # t-SNE
    tsne = TSNE(n_components=2, random_state=42, perplexity=min(30, len(features)-1))
    tsne_features = tsne.fit_transform(features)

    scatter = axes[idx, 0].scatter(tsne_features[:, 0], tsne_features[:, 1],
                                   c=clusters, cmap='tab10', alpha=0.7, s=50,
                                   edgecolors='black', linewidth=0.5)
    axes[idx, 0].set_title(f'{name} (t-SNE)\nSil={sil:.3f}, DB={db:.3f}',
                          fontsize=13, fontweight='bold')
    axes[idx, 0].set_xlabel('t-SNE 1', fontsize=11)
    axes[idx, 0].set_ylabel('t-SNE 2', fontsize=11)
    plt.colorbar(scatter, ax=axes[idx, 0], label='Cluster')
    axes[idx, 0].grid(True, alpha=0.3)

    # UMAP
    reducer = umap.UMAP(random_state=42, n_neighbors=15, min_dist=0.1)
    umap_features = reducer.fit_transform(features)

    scatter = axes[idx, 1].scatter(umap_features[:, 0], umap_features[:, 1],
                                   c=clusters, cmap='tab10', alpha=0.7, s=50,
                                   edgecolors='black', linewidth=0.5)
    axes[idx, 1].set_title(f'{name} (UMAP)\nSil={sil:.3f}, DB={db:.3f}',
                          fontsize=13, fontweight='bold')
    axes[idx, 1].set_xlabel('UMAP 1', fontsize=11)
    axes[idx, 1].set_ylabel('UMAP 2', fontsize=11)
    plt.colorbar(scatter, ax=axes[idx, 1], label='Cluster')
    axes[idx, 1].grid(True, alpha=0.3)

plt.tight_layout()
visualizations_output_dir = os.path.join(base_path, 'visualizations')
os.makedirs(visualizations_output_dir, exist_ok=True)
plt.savefig(os.path.join(visualizations_output_dir, 'latent_space_comparison_hard.png'), dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Generating latent space visualizations...

# %%
# ========================================
# CELL 13: Cluster Distribution Over Labels
# ========================================
if has_labels:
    print("\nGenerating cluster vs label distribution...")

    fig, axes = plt.subplots(1, len(vae_methods), figsize=(6*len(vae_methods), 5))

    if len(vae_methods) == 1:
        axes = [axes]

    for idx, (name, features) in enumerate(vae_methods.items()):
        clusters = vae_clusters_dict[name]

        # Create confusion matrix
        confusion_mat = pd.crosstab(clusters, labels_encoded,
                                   rownames=['Cluster'], colnames=['True Label'])

        sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues',
                   ax=axes[idx], cbar_kws={'label': 'Count'})
        axes[idx].set_title(f'{name}\nCluster vs Label Distribution',
                           fontsize=12, fontweight='bold')
        axes[idx].set_xlabel('True Label', fontsize=11)
        axes[idx].set_ylabel('Cluster ID', fontsize=11)

    plt.tight_layout()
    visualizations_output_dir = os.path.join(base_path, 'visualizations')
    os.makedirs(visualizations_output_dir, exist_ok=True)
    plt.savefig(os.path.join(visualizations_output_dir, 'cluster_label_distribution_hard.png'), dpi=300, bbox_inches='tight')
    plt.show()
# Out:
# Generating cluster vs label distribution...

# %%
print("\nGenerating reconstruction quality plots...")

n_samples = 5
sample_idx = np.random.choice(len(spec_flat_normalized), n_samples, replace=False)

fig, axes = plt.subplots(len(vae_methods)+1, n_samples, figsize=(20, 4*(len(vae_methods)+1)))

# Original
for i in range(n_samples):
    axes[0, i].plot(spec_flat_normalized[sample_idx[i], :200], alpha=0.7, linewidth=1)
    axes[0, i].set_title(f'Original {sample_idx[i]}', fontsize=10)
    axes[0, i].set_ylim([-4, 4])

axes[0, 0].set_ylabel('Original', fontsize=12, fontweight='bold')

# Reconstructions
row = 1
for name in vae_methods.keys():
    reconstructed = None # Initialize to None
    if name == 'Beta-VAE':
        # Explicitly encode and decode for reconstruction
        z_mean_sampled, _, _ = beta_encoder.predict(spec_flat_normalized[sample_idx], verbose=0)
        reconstructed = beta_decoder.predict(z_mean_sampled, verbose=0)
    elif name == 'CVAE' and cvae:
        # Ensure labels_onehot is available and has correct shape for CVAE reconstruction
        if 'labels_onehot' in globals() and labels_onehot is not None and len(labels_onehot) > 0:
            # Need to select the correct one-hot labels for the sampled indices
            reconstructed = cvae.decoder.predict([z_mean_cvae_features[sample_idx], labels_onehot[sample_idx]], verbose=0)
        else:
            print(f"Warning: Skipping CVAE reconstruction for {name} as labels_onehot is not available or empty.")
    elif name == 'Multi-Modal VAE':
        _, _, z_mm_sampled = mm_encoder.predict([spec_flat_normalized[sample_idx], lyrics_normalized[sample_idx]], verbose=0)
        reconstructed, _ = mm_decoder.predict(z_mm_sampled, verbose=0)

    if reconstructed is not None:
        for i in range(n_samples):
            axes[row, i].plot(reconstructed[i, :200], alpha=0.7, linewidth=1, color='orange')
            axes[row, i].set_title(f'Recon {sample_idx[i]}', fontsize=10)
            axes[row, i].set_ylim([-4, 4])

        axes[row, 0].set_ylabel(name, fontsize=12, fontweight='bold')
    row += 1

plt.suptitle('Reconstruction Quality Comparison', fontsize=14, fontweight='bold')
plt.tight_layout()
visualizations_output_dir = os.path.join(base_path, 'visualizations')
os.makedirs(visualizations_output_dir, exist_ok=True)
plt.savefig(os.path.join(visualizations_output_dir, 'reconstruction_quality_hard.png'), dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Generating reconstruction quality plots...
# WARNING:tensorflow:5 out of the last 27 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e2c7d1320c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
print("\n" + "="*60)
print("SAVING MODELS AND RESULTS")
print("="*60)

# Create directories for models and latent features/clusters
models_output_dir = os.path.join(base_path, 'models')
os.makedirs(models_output_dir, exist_ok=True)

# Save models
beta_vae.save(os.path.join(models_output_dir, 'beta_vae_model.h5'))
beta_encoder.save(os.path.join(models_output_dir, 'beta_encoder_model.h5'))
print("✓ Beta-VAE saved")

if cvae:
    cvae.save(os.path.join(models_output_dir, 'cvae_model.h5'))
    cvae_encoder.save(os.path.join(models_output_dir, 'cvae_encoder_model.h5'))
    print(" CVAE saved")

mm_vae.save(os.path.join(models_output_dir, 'mm_vae_model.h5'))
mm_encoder.save(os.path.join(models_output_dir, 'mm_encoder_model.h5'))
print("✓ Multi-Modal VAE saved")

# Save latent features
np.save(os.path.join(base_path, 'latent_features_beta.npy'), z_mean_beta_features)
np.save(os.path.join(base_path, 'latent_features_mm.npy'), z_mean_mm_features)
if z_mean_cvae_features is not None:
    np.save(os.path.join(base_path, 'latent_features_cvae.npy'), z_mean_cvae_features)
print(" Latent features saved")

# Save clusters
if 'vae_clusters_dict' in globals(): # Ensure vae_clusters_dict exists
    for name, clusters in vae_clusters_dict.items():
        safe_name = name.replace(' ', '_').replace('-', '_').lower()
        np.save(os.path.join(base_path, f'clusters_{safe_name}.npy'), clusters)
print(" Cluster assignments saved")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ============================================================
# SAVING MODELS AND RESULTS
# ============================================================
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✓ Beta-VAE saved
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#  CVAE saved
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✓ Multi-Modal VAE saved
#  Latent features saved
#  Cluster assignments saved

# %%
print("\n" + "="*60)
print("GENERATING REPORT SUMMARY")
print("="*60)

# Helper to conditionally get epochs if history object exists
def get_epochs(history_obj):
    return str(len(history_obj.history['loss'])) if history_obj else 'N/A'

# Helper to conditionally get PCA explained variance
def get_pca_variance_summary():
    if 'pca' in globals() and pca is not None:
        return f"{pca.explained_variance_ratio_.sum():.2%} variance"
    return "N/A variance"

# Helper to conditionally get optimal k
def get_optimal_k_summary():
    if 'optimal_k' in globals():
        return optimal_k
    return 'N/A'

# Helper to conditionally get best result metrics
def get_best_metric_summary(metric_type, results_df_arg):
    if results_df_arg is not None and not results_df_arg.empty:
        if metric_type == 'silhouette':
            best_row = results_df_arg.loc[results_df_arg['silhouette'].idxmax()]
            return f"Method: {best_row['method']}\n  Score: {best_row['silhouette']:.4f}\n  Balance: {best_row['balance_ratio']:.3f}"
        elif metric_type == 'davies_bouldin':
            best_row = results_df_arg.loc[results_df_arg['davies_bouldin'].idxmin()]
            return f"Method: {best_row['method']}\n  Score: {best_row['davies_bouldin']:.4f}\n  Balance: {best_row['balance_ratio']:.3f}"
        elif metric_type == 'nmi' and has_labels:
            best_row = results_df_arg.loc[results_df_arg['nmi'].idxmax()]
            return f"Method: {best_row['method']}\n  NMI: {best_row['nmi']:.4f}\n  ARI: {best_row['ari']:.4f}\n  Purity: {best_row['purity']:.4f}"
    return "N/A"

# Helper to determine multi-modal fusion finding
def get_multi_modal_fusion_summary(results_df_arg):
    if results_df_arg is not None and not results_df_arg.empty:
        mm_silhouettes = results_df_arg[results_df_arg['method'].str.contains('Multi-Modal')]['silhouette']
        beta_vae_silhouettes = results_df_arg[results_df_arg['method'].str.contains('Beta-VAE')]['silhouette']
        if not mm_silhouettes.empty and not beta_vae_silhouettes.empty and mm_silhouettes.mean() > beta_vae_silhouettes.mean():
            return 'improved'
    return 'did not improve'

# Helper to determine VAE vs baseline finding
def get_vae_vs_baseline_summary(results_df_arg):
    if results_df_arg is not None and not results_df_arg.empty:
        vae_silhouettes = results_df_arg[results_df_arg['method'].str.contains('VAE')]['silhouette']
        baseline_silhouettes = results_df_arg[results_df_arg['method'].str.contains('PCA|Autoencoder|Spectral')]['silhouette']
        if not vae_silhouettes.empty and not baseline_silhouettes.empty and vae_silhouettes.mean() > baseline_silhouettes.mean():
            return 'outperformed'
    return 'were comparable to'

# Safely get results_df from globals, default to None if not defined
results_df_safe = globals().get('results_df', None)

summary = f"""


DATASET:
- Total samples: {len(spec_flat_normalized)}
- Spectrogram features: {spec_flat_normalized.shape[1]}
- Lyrics embedding dimension: {lyrics_normalized.shape[1]}
- Number of classes: {n_classes if has_labels else 'N/A (unsupervised)'}

MODELS IMPLEMENTED:
1. Beta-VAE (β={beta})
   - Latent dimension: {latent_dim}
   - Purpose: Disentangled representations
   - Training epochs: {get_epochs(history_beta)}

2. {'Conditional VAE (CVAE)' if cvae else 'CVAE (skipped - no labels)'}
   {'- Latent dimension: ' + str(latent_dim_cvae) if cvae else ''}
   {'- Conditioned on: ' + label_col if cvae and has_labels else ''}
   {'- Training epochs: ' + (get_epochs(history_cvae) if 'history_cvae' in locals() and cvae else 'N/A')}

3. Multi-Modal VAE
   - Latent dimension: {latent_dim_mm}
   - Modalities: Audio spectrograms + Lyrics embeddings
   - Training epochs: {get_epochs(history_mm) if 'history_mm' in locals() else 'N/A'}

BASELINES:
- PCA (128 components, {get_pca_variance_summary()})
- Autoencoder (128-dim encoding)
- Direct Spectral Features

CLUSTERING ALGORITHMS:
- K-Means (k={get_optimal_k_summary()})
- Agglomerative Clustering (k={get_optimal_k_summary()})
- DBSCAN (eps=0.5, min_samples=5)

BEST RESULTS:
{'='*40}
Silhouette Score:
  {get_best_metric_summary('silhouette', results_df_safe)}

Davies-Bouldin Index:
  {get_best_metric_summary('davies_bouldin', results_df_safe)}

{f'NMI Score:\n  {get_best_metric_summary('nmi', results_df_safe)}' if has_labels else 'Label-based metrics: N/A (unsupervised)'}

KEY FINDINGS:
1. Multi-modal fusion {get_multi_modal_fusion_summary(results_df_safe)} clustering quality
2. Beta-VAE with β={beta} successfully learned disentangled representations
3. {'CVAE conditioning on labels enhanced cluster alignment' if cvae else 'CVAE not applicable without labels'}
4. VAE-based methods {get_vae_vs_baseline_summary(results_df_safe)} baseline methods

FILES GENERATED:
✓ All trained models (.h5)
✓ Latent features (.npy)
✓ Cluster assignments (.npy)
✓ Comprehensive metrics (CSV)
✓ Training history plots
✓ Latent space visualizations (t-SNE, UMAP)
✓ Reconstruction quality plots
✓ Cluster distribution analysis
"""

print(summary)

# Ensure the directory exists before saving the report summary
output_summary_path = os.path.join(base_path, 'report_summary_hard_task.txt')
os.makedirs(os.path.dirname(output_summary_path), exist_ok=True)
with open(output_summary_path, 'w') as f:
    f.write(summary)
    f.write("\n\nDETAILED METRICS:\n")
    f.write("="*60 + "\n")
    f.write(results_df_safe.to_string(index=False) if results_df_safe is not None and not results_df_safe.empty else "No detailed metrics available.")

print(f"\n✓ Report summary saved to: {output_summary_path}")
# Out:
# ============================================================
# GENERATING REPORT SUMMARY
# ============================================================
#
#
#
# DATASET:
# - Total samples: 683
# - Spectrogram features: 32768
# - Lyrics embedding dimension: 384
# - Number of classes: 5
#
# MODELS IMPLEMENTED:
# 1. Beta-VAE (β=4.0)
#    - Latent dimension: 128
#    - Purpose: Disentangled representations
#    - Training epochs: 21
#
# 2. Conditional VAE (CVAE)
#    - Latent dimension: 128
#    - Conditioned on: genre
#    - Training epochs: 55
#
# 3. Multi-Modal VAE
#    - Latent dimension: 128
#    - Modalities: Audio spectrograms + Lyrics embeddings
#    - Training epochs: 33
#
# BASELINES:
# - PCA (128 components, 74.20% variance)
# - Autoencoder (128-dim encoding)
# - Direct Spectral Features
#
# CLUSTERING ALGORITHMS:
# - K-Means (k=5)
# - Agglomerative Clustering (k=5)
# - DBSCAN (eps=0.5, min_samples=5)
#
# BEST RESULTS:
# ========================================
# Silhouette Score:
#   Method: CVAE + K-Means
#   Score: 0.9476
#   Balance: 0.001
#
# Davies-Bouldin Index:
#   Method: CVAE + K-Means
#   Score: 0.0289
#   Balance: 0.001
#
# NMI Score:
#   Method: Spectral + K-Means
#   NMI: 0.0879
#   ARI: 0.0669
#   Purity: 0.3880
#
# KEY FINDINGS:
# 1. Multi-modal fusion did not improve clustering quality
# 2. Beta-VAE with β=4.0 successfully learned disentangled representations
# 3. CVAE conditioning on labels enhanced cluster alignment
# 4. VAE-based methods outperformed baseline methods
#
# FILES GENERATED:
# ✓ All trained models (.h5)
# ✓ Latent features (.npy)
# ✓ Cluster assignments (.npy)
# ✓ Comprehensive metrics (CSV)
# ✓ Training history plots
# ✓ Latent space visualizations (t-SNE, UMAP)
# ✓ Reconstruction quality plots
# ✓ Cluster distribution analysis
#
#
# ✓ Report summary saved to: /content/drive/MyDrive/VAE for Hybrid Language Music Clustering/report_summary_hard_task.txt
